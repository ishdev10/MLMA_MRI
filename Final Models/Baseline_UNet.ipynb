# %% [markdown]
# # **Using MRI for Brain Tumor Detection and Segmentation**
#
# This notebook contains the code to process the BraTS 2020 data, and implement a baseline UNet model for brain tumor segmentation. It has been adapted from the *Brain Tumor Segmentation using U-Net* notebook code found on Kaggle: https://www.kaggle.com/code/zeeshanlatif/brain-tumor-segmentation-using-u-net/notebook#14

# %% [markdown]
# ## **Dataset Information**
# The Brain Tumor Segmentation (BraTS) 2020 dataset is a collection of multimodal Magnetic Resonance Imaging (MRI) scans used for the segmentation of brain tumors.
#
# It includes MRI scans from glioma patients, providing four different MRI modalities:
#
# 1. **T1**
# 2. **T1ce**: Post-contrast T1-weighted
# 3. **T2**
# 4. **FLAIR**: T2 Fluid Attenuated Inversion Recovery
#
# These scans come with expert-annotated segmentation masks that delineate the tumor into various sub-regions, such as the necrotic and non-enhancing tumor core, the peritumoral edema, and the enhancing tumor.
#
# Annotations (labels):
# 1. **Label 0:** Not Tumor (NT) volume
# 2. **Label 1:** Necrotic and non-enhancing tumor core (NCR/NET)
# 3. **Label 2:** Peritumoral edema (ED)
# 4. **Label 3:** GD-enhancing tumor (ET)

# %% [markdown]
# ## **Load and Explore Dataset**

# %%
import os
import cv2
import random
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nibabel as nib
import keras
import tensorflow.keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create distribution strategy (for Kaggle with 2 GPUs)
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 1

# %%
Train_Path = "/content/drive/MyDrive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/"

# %%
# Load .nii files as numpy arrays
test_image_flair = nib.load(Train_Path + "BraTS20_Training_306/BraTS20_Training_306_flair.nii").get_fdata()
print("Shape: ", test_image_flair.shape)
print("Dtype: ", test_image_flair.dtype)

# Rescale images
scaler = MinMaxScaler()
test_image_flair = scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

# rescaling t1
test_image_t1 = nib.load(Train_Path + 'BraTS20_Training_306/BraTS20_Training_306_t1.nii').get_fdata()
test_image_t1 = scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

# rescaling t1ce
test_image_t1ce = nib.load(Train_Path + 'BraTS20_Training_306/BraTS20_Training_306_t1ce.nii').get_fdata()
test_image_t1ce = scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

# rescaling t2
test_image_t2 = nib.load(Train_Path + 'BraTS20_Training_306/BraTS20_Training_306_t2.nii').get_fdata()
test_image_t2 = scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

# no rescale for mask
test_image_seg = nib.load(Train_Path + 'BraTS20_Training_306/BraTS20_Training_306_seg.nii').get_fdata()
# Out:
# Shape:  (240, 240, 155)
# Dtype:  float64

# %%
slice = 95

print("Slice Number: " + str(slice))

plt.figure(figsize=(12, 8))

# T1
plt.subplot(2, 3, 1)
plt.imshow(test_image_t1[:,:,slice], cmap='gray')
plt.title('T1')

# T1ce
plt.subplot(2, 3, 2)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1ce')

# T2
plt.subplot(2, 3, 3)
plt.imshow(test_image_t2[:,:,slice], cmap='gray')
plt.title('T2')

# Flair
plt.subplot(2, 3, 4)
plt.imshow(test_image_flair[:,:,slice], cmap='gray')
plt.title('FLAIR')

# Mask
plt.subplot(2, 3, 5)
plt.imshow(test_image_seg[:,:,slice])
plt.title('Mask')
plt.show()

cmap = matplotlib.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = matplotlib.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)
# Out:
# Slice Number: 95

# %%
# Modality shape
print("Modality: ", test_image_t1.shape)

# Segmentation shape
print("Segmentation: ", test_image_seg.shape)
# Out:
# Modality:  (240, 240, 155)
# Segmentation:  (240, 240, 155)

# %%
slice = 95

print("Slice number: " + str(slice))

plt.figure(figsize=(12, 8))

# T1 - Transverse View
plt.subplot(1, 3, 1)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1 - Transverse View')

# T1 - Frontal View
plt.subplot(1, 3, 2)
plt.imshow(rotate(test_image_t1ce[:,slice,:], 90, resize=True), cmap='gray')
plt.title('T1 - Frontal View')

# T1 - Sagittal View
plt.subplot(1, 3, 3)
plt.imshow(rotate(test_image_t1ce[slice,:,:], 90, resize=True), cmap='gray')
plt.title('T1 - Sagittal View')
plt.show()
# Out:
# Slice number: 95

# %%
# Montage
plt.imshow(rotate(montage(test_image_t1ce[:,:,:]), 90, resize=True), cmap ='gray');

# %%
# Isolation of class 0
seg_0 = test_image_seg.copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = test_image_seg.copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = test_image_seg.copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_4 = test_image_seg.copy()
seg_4[seg_4 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 4']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, ax = plt.subplots(1, 5, figsize=(20, 20))

ax[0].imshow(test_image_seg[:,:, slice], cmap=cmap, norm=norm)
ax[0].set_title('Original Segmentation')
ax[0].legend(handles=legend, loc='lower left')

ax[1].imshow(seg_0[:,:, slice], cmap=cmap, norm=norm)
ax[1].set_title('Not Tumor (class 0)')

ax[2].imshow(seg_1[:,:, slice], cmap=cmap, norm=norm)
ax[2].set_title('Non-Enhancing Tumor (class 1)')

ax[3].imshow(seg_2[:,:, slice], cmap=cmap, norm=norm)
ax[3].set_title('Edema (class 2)')

ax[4].imshow(seg_4[:,:, slice], cmap=cmap, norm=norm)
ax[4].set_title('Enhancing Tumor (class 4)')

plt.show()

# %% [markdown]
# ## **Splitting the Data**
#
# * **Training Set:** 70%
# * **Validation Set:** 20%
# * **Testing Set:** 10%

# %%
train_and_val_directories = [f.path for f in os.scandir(Train_Path) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories)

# First, split into 70% training and 30% temporary set
train_ids, temp_ids = train_test_split(train_and_test_ids, test_size=0.30, random_state=42)

# Then, split the temporary set equally into 20% validation and 10% testing
val_ids, test_ids = train_test_split(temp_ids, test_size=0.33, random_state=42)

print(f"Train length: {len(train_ids)}")
print(f"Validation length: {len(val_ids)}")
print(f"Test length: {len(test_ids)}")
# Out:
# Train length: 258
# Validation length: 74
# Test length: 37

# %%
plt.bar(["Train","Valid","Test"],
        [len(train_ids), len(val_ids), len(test_ids)],
        align='center',
        color=[ 'green','red', 'blue'],
        label=["Train", "Valid", "Test"]
       )

plt.legend()

plt.ylabel('Number of Images')
plt.title('Data Distribution')

plt.show()

# %% [markdown]
# ## **DataGenerator**
# 1. Retrieve paths
# 2. Load data
# 3. Create arrays
#
# Additional preprocessing steps include:
# * Axial plane
# * One-Hot Encoding
# * Resize images

# %%
# Define seg-areas
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE',
    2 : 'EDEMA',
    3 : 'ENHANCING'
}

# Select Slices and Image Size
VOLUME_SLICES = 100
VOLUME_START_AT = 22
IMG_SIZE=128

# %%
class DataGenerator(keras.utils.Sequence):
    """Generates data for Keras."""
    def __init__(self, list_IDs, dim=(IMG_SIZE, IMG_SIZE), batch_size=4, n_channels=4, shuffle=True, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        "Number of batches per epoch"
        return int(np.ceil(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        "One batch"
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        Batch_ids = [self.list_IDs[k] for k in indexes]
        X, Y = self.__data_generation(Batch_ids)
        #print("Batch max value:", np.max(X))
        return X, Y

    def on_epoch_end(self):
        "Updates indexes after each epoch"
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        "Data containing batch-sized samples"
        batch_size_actual = len(Batch_ids)
        # Initialize X to hold each slice for each case
        X = np.zeros((batch_size_actual * VOLUME_SLICES, *self.dim, self.n_channels), dtype=np.float32)
        # y is initially defined with shape (batch_size * VOLUME_SLICES, 240, 240)
        y = np.zeros((batch_size_actual * VOLUME_SLICES, 240, 240), dtype=np.int32)

        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(Train_Path, i)

            t1 = nib.load(os.path.join(case_path, f'{i}_t1.nii')).get_fdata()
            t2 = nib.load(os.path.join(case_path, f'{i}_t2.nii')).get_fdata()
            flair = nib.load(os.path.join(case_path, f'{i}_flair.nii')).get_fdata()
            t1ce = nib.load(os.path.join(case_path, f'{i}_t1ce.nii')).get_fdata()
            seg = nib.load(os.path.join(case_path, f'{i}_seg.nii')).get_fdata()

            for j in range(VOLUME_SLICES):
                slice_index = j + VOLUME_START_AT
                # Rezise T1 and T2
                X[j + VOLUME_SLICES * c, :, :, 0] = cv2.resize(t1[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
                X[j + VOLUME_SLICES * c, :, :, 2] = cv2.resize(t2[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
                # Resize the flair and t1ce images to (IMG_SIZE, IMG_SIZE)
                X[j + VOLUME_SLICES * c, :, :, 1] = cv2.resize(flair[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
                X[j + VOLUME_SLICES * c, :, :, 3] = cv2.resize(t1ce[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
                # Resize the segmentation to 240x240
                y[j + VOLUME_SLICES * c] = cv2.resize(seg[:, :, slice_index], (240, 240))

        # Replace label 4 with 3 in the segmentation
        y[y == 4] = 3
        # Convert y to one-hot encoding with 4 classes
        mask = tf.one_hot(y, 4)
        # Resize mask to (IMG_SIZE, IMG_SIZE) for each slice
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE))

        # Normalize X safely (avoid division by zero)
        max_val = np.max(X)
        if max_val != 0:
            X = X / max_val
        return X, Y

# Usage:
training_generator = DataGenerator(train_ids, batch_size=4, n_channels=4)
valid_generator = DataGenerator(val_ids, batch_size=4, n_channels=4)
test_generator = DataGenerator(test_ids, batch_size=4, n_channels=4)

# %% [markdown]
# ## **Loss Function and Evaluation Metrics**

# %%
# DiceCoefMetric (for all classes)
class DiceCoefMetric(tf.keras.metrics.Metric):
    def __init__(self, num_classes=4, smooth=1.0, name='dice_coef', **kwargs):
        super(DiceCoefMetric, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.smooth = smooth
        self.total_dice = self.add_weight(name='total_dice', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        dice_sum = 0.0
        for i in range(self.num_classes):
            y_true_f = tf.reshape(y_true[..., i], [-1])
            y_pred_f = tf.reshape(y_pred[..., i], [-1])
            intersection = tf.reduce_sum(y_true_f * y_pred_f)
            dice = (2. * intersection + self.smooth) / (
                tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + self.smooth)
            dice_sum += dice
        dice_avg = dice_sum / self.num_classes
        self.total_dice.assign_add(dice_avg)
        self.count.assign_add(1.0)

    def result(self):
        return self.total_dice / self.count

    def reset_states(self):
        self.total_dice.assign(0.0)
        self.count.assign(0.0)

# DiceCoefNecroticMetric
class DiceCoefNecroticMetric(tf.keras.metrics.Metric):
    def __init__(self, smooth=1e-6, name='dice_coef_necrotic', **kwargs):
        super(DiceCoefNecroticMetric, self).__init__(name=name, **kwargs)
        self.smooth = smooth
        self.total_dice = self.add_weight(name='total_dice_necrotic', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_channel = tf.reshape(y_true[..., 1], [-1])
        y_pred_channel = tf.reshape(y_pred[..., 1], [-1])
        intersection = tf.reduce_sum(tf.abs(y_true_channel * y_pred_channel))
        dice = (2. * intersection) / (
            tf.reduce_sum(tf.square(y_true_channel)) + tf.reduce_sum(tf.square(y_pred_channel)) + self.smooth)
        self.total_dice.assign_add(dice)
        self.count.assign_add(1.0)

    def result(self):
        return self.total_dice / self.count

    def reset_states(self):
        self.total_dice.assign(0.0)
        self.count.assign(0.0)

# DiceCoefEdemaMetric
class DiceCoefEdemaMetric(tf.keras.metrics.Metric):
    def __init__(self, smooth=1e-6, name='dice_coef_edema', **kwargs):
        super(DiceCoefEdemaMetric, self).__init__(name=name, **kwargs)
        self.smooth = smooth
        self.total_dice = self.add_weight(name='total_dice_edema', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_channel = tf.reshape(y_true[..., 2], [-1])
        y_pred_channel = tf.reshape(y_pred[..., 2], [-1])
        intersection = tf.reduce_sum(y_true_channel * y_pred_channel)
        dice = (2. * intersection) / (
            tf.reduce_sum(tf.square(y_true_channel)) + tf.reduce_sum(tf.square(y_pred_channel)) + self.smooth)
        self.total_dice.assign_add(dice)
        self.count.assign_add(1.0)

    def result(self):
        return self.total_dice / self.count

    def reset_states(self):
        self.total_dice.assign(0.0)
        self.count.assign(0.0)

# DiceCoefEnhancingMetric
class DiceCoefEnhancingMetric(tf.keras.metrics.Metric):
    def __init__(self, smooth=1e-6, name='dice_coef_enhancing', **kwargs):
        super(DiceCoefEnhancingMetric, self).__init__(name=name, **kwargs)
        self.smooth = smooth
        self.total_dice = self.add_weight(name='total_dice_enhancing', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_channel = tf.reshape(y_true[..., 3], [-1])
        y_pred_channel = tf.reshape(y_pred[..., 3], [-1])
        intersection = tf.reduce_sum(tf.abs(y_true_channel * y_pred_channel))
        dice = (2. * intersection) / (
            tf.reduce_sum(tf.square(y_true_channel)) + tf.reduce_sum(tf.square(y_pred_channel)) + self.smooth)
        self.total_dice.assign_add(dice)
        self.count.assign_add(1.0)

    def result(self):
        return self.total_dice / self.count

    def reset_states(self):
        self.total_dice.assign(0.0)
        self.count.assign(0.0)

# PrecisionMetric
class PrecisionMetric(tf.keras.metrics.Metric):
    def __init__(self, name='precision', **kwargs):
        super(PrecisionMetric, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_true_pred = tf.round(tf.clip_by_value(y_true * y_pred, 0, 1))
        y_pred_rounded = tf.round(tf.clip_by_value(y_pred, 0, 1))
        tp = tf.reduce_sum(y_true_pred)
        pp = tf.reduce_sum(y_pred_rounded)
        self.true_positives.assign_add(tp)
        self.predicted_positives.assign_add(pp)

    def result(self):
        return self.true_positives / (self.predicted_positives + tf.keras.backend.epsilon())

    def reset_states(self):
        self.true_positives.assign(0.0)
        self.predicted_positives.assign(0.0)

# SensitivityMetric (Recall)
class SensitivityMetric(tf.keras.metrics.Metric):
    def __init__(self, name='sensitivity', **kwargs):
        super(SensitivityMetric, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.possible_positives = self.add_weight(name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_true_pred = tf.round(tf.clip_by_value(y_true * y_pred, 0, 1))
        y_true_rounded = tf.round(tf.clip_by_value(y_true, 0, 1))
        tp = tf.reduce_sum(y_true_pred)
        pp = tf.reduce_sum(y_true_rounded)
        self.true_positives.assign_add(tp)
        self.possible_positives.assign_add(pp)

    def result(self):
        return self.true_positives / (self.possible_positives + tf.keras.backend.epsilon())

    def reset_states(self):
        self.true_positives.assign(0.0)
        self.possible_positives.assign(0.0)

# SpecificityMetric
class SpecificityMetric(tf.keras.metrics.Metric):
    def __init__(self, name='specificity', **kwargs):
        super(SpecificityMetric, self).__init__(name=name, **kwargs)
        self.true_negatives = self.add_weight(name='tn', initializer='zeros')
        self.possible_negatives = self.add_weight(name='pn', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        one_minus_y_true = 1 - y_true
        one_minus_y_pred = 1 - y_pred
        tn = tf.reduce_sum(tf.round(tf.clip_by_value(one_minus_y_true * one_minus_y_pred, 0, 1)))
        pn = tf.reduce_sum(tf.round(tf.clip_by_value(one_minus_y_true, 0, 1)))
        self.true_negatives.assign_add(tn)
        self.possible_negatives.assign_add(pn)

    def result(self):
        return self.true_negatives / (self.possible_negatives + tf.keras.backend.epsilon())

    def reset_states(self):
        self.true_negatives.assign(0.0)
        self.possible_negatives.assign(0.0)

# %% [markdown]
# ## **Define UNet Segmentation Model**

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# ![Unet.png](data:image/png;base64,...)

# %%
# Build model
with strategy.scope():
    input_layer = tf.keras.layers.Input((IMG_SIZE, IMG_SIZE, 4))
    model = build_unet(input_layer, 'he_normal', 0.2)
    model.compile(
        loss="categorical_crossentropy",
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
        metrics=[
            'accuracy',
            tf.keras.metrics.MeanIoU(num_classes=4),
            DiceCoefMetric(),
            DiceCoefNecroticMetric(),
            DiceCoefEdemaMetric(),
            DiceCoefEnhancingMetric(),
            PrecisionMetric(),
            SensitivityMetric(),
            SpecificityMetric()
        ]
    )

# %%
# Set Up Callbacks
callbacks = [
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                            patience=2, min_lr=0.000001, verbose=1),
      keras.callbacks.ModelCheckpoint(filepath='model_.{epoch:02d}-{val_loss:.6f}.weights.h5',
                                verbose=1, save_best_only=True, save_weights_only=True),
      CSVLogger('/content/drive/MyDrive/Baseline_UNet/training.log', separator=',', append=False)
    ]

# %% [markdown]
# ## **Train and Save the Model**

# %%
history = model.fit(
    training_generator,
    epochs=25,
    callbacks=callbacks,
    validation_data=valid_generator
)

model.save("/content/drive/MyDrive/Baseline_UNet/Baseline_UNet.keras")
# Out:
# Epoch 1/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.8922 - dice_coef: 0.2188 - dice_coef_edema: 0.0493 - dice_coef_enhancing: 0.0263 - dice_coef_necrotic: 0.0254 - loss: 0.5051 - mean_io_u: 0.4160 - precision: 0.9691 - sensitivity: 0.7546 - specificity: 0.9953
# Epoch 1: val_loss improved from inf to 0.07544, saving model to model_.01-0.075444.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1197s 18s/step - accuracy: 0.8933 - dice_coef: 0.2192 - dice_coef_edema: 0.0496 - dice_coef_enhancing: 0.0264 - dice_coef_necrotic: 0.0257 - loss: 0.5010 - mean_io_u: 0.4162 - precision: 0.9693 - sensitivity: 0.7570 - specificity: 0.9952 - val_accuracy: 0.9832 - val_dice_coef: 0.2734 - val_dice_coef_edema: 0.1337 - val_dice_coef_enhancing: 0.0713 - val_dice_coef_necrotic: 0.0803 - val_loss: 0.0754 - val_mean_io_u: 0.4991 - val_precision: 0.9830 - val_sensitivity: 0.9830 - val_specificity: 0.9944 - learning_rate: 3.0000e-04
# Epoch 2/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9843 - dice_coef: 0.2740 - dice_coef_edema: 0.1090 - dice_coef_enhancing: 0.0595 - dice_coef_necrotic: 0.0808 - loss: 0.0692 - mean_io_u: 0.5271 - precision: 0.9842 - sensitivity: 0.9842 - specificity: 0.9948
# Epoch 2: val_loss improved from 0.07544 to 0.07019, saving model to model_.02-0.070187.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9843 - dice_coef: 0.2741 - dice_coef_edema: 0.1092 - dice_coef_enhancing: 0.0598 - dice_coef_necrotic: 0.0811 - loss: 0.0692 - mean_io_u: 0.5270 - precision: 0.9842 - sensitivity: 0.9842 - specificity: 0.9948 - val_accuracy: 0.9832 - val_dice_coef: 0.2943 - val_dice_coef_edema: 0.2163 - val_dice_coef_enhancing: 0.1603 - val_dice_coef_necrotic: 0.1632 - val_loss: 0.0702 - val_mean_io_u: 0.4718 - val_precision: 0.9856 - val_sensitivity: 0.9823 - val_specificity: 0.9952 - learning_rate: 3.0000e-04
# Epoch 3/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9821 - dice_coef: 0.3072 - dice_coef_edema: 0.1874 - dice_coef_enhancing: 0.1306 - dice_coef_necrotic: 0.1829 - loss: 0.0675 - mean_io_u: 0.5650 - precision: 0.9852 - sensitivity: 0.9812 - specificity: 0.9951
# Epoch 3: val_loss improved from 0.07019 to 0.06547, saving model to model_.03-0.065467.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9822 - dice_coef: 0.3072 - dice_coef_edema: 0.1874 - dice_coef_enhancing: 0.1307 - dice_coef_necrotic: 0.1830 - loss: 0.0674 - mean_io_u: 0.5649 - precision: 0.9852 - sensitivity: 0.9812 - specificity: 0.9951 - val_accuracy: 0.9832 - val_dice_coef: 0.3066 - val_dice_coef_edema: 0.2619 - val_dice_coef_enhancing: 0.1903 - val_dice_coef_necrotic: 0.2069 - val_loss: 0.0655 - val_mean_io_u: 0.5132 - val_precision: 0.9875 - val_sensitivity: 0.9821 - val_specificity: 0.9958 - learning_rate: 3.0000e-04
# Epoch 4/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9836 - dice_coef: 0.3263 - dice_coef_edema: 0.2291 - dice_coef_enhancing: 0.1776 - dice_coef_necrotic: 0.2329 - loss: 0.0584 - mean_io_u: 0.5956 - precision: 0.9886 - sensitivity: 0.9817 - specificity: 0.9962
# Epoch 4: val_loss improved from 0.06547 to 0.05974, saving model to model_.04-0.059736.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9836 - dice_coef: 0.3263 - dice_coef_edema: 0.2291 - dice_coef_enhancing: 0.1776 - dice_coef_necrotic: 0.2327 - loss: 0.0584 - mean_io_u: 0.5958 - precision: 0.9886 - sensitivity: 0.9817 - specificity: 0.9962 - val_accuracy: 0.9832 - val_dice_coef: 0.3245 - val_dice_coef_edema: 0.2764 - val_dice_coef_enhancing: 0.2293 - val_dice_coef_necrotic: 0.2469 - val_loss: 0.0597 - val_mean_io_u: 0.6469 - val_precision: 0.9907 - val_sensitivity: 0.9790 - val_specificity: 0.9968 - learning_rate: 3.0000e-04
# Epoch 5/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9844 - dice_coef: 0.3469 - dice_coef_edema: 0.2667 - dice_coef_enhancing: 0.2233 - dice_coef_necrotic: 0.2729 - loss: 0.0498 - mean_io_u: 0.6175 - precision: 0.9911 - sensitivity: 0.9820 - specificity: 0.9970
# Epoch 5: val_loss improved from 0.05974 to 0.04639, saving model to model_.05-0.046387.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9844 - dice_coef: 0.3472 - dice_coef_edema: 0.2671 - dice_coef_enhancing: 0.2238 - dice_coef_necrotic: 0.2731 - loss: 0.0497 - mean_io_u: 0.6175 - precision: 0.9911 - sensitivity: 0.9820 - specificity: 0.9970 - val_accuracy: 0.9837 - val_dice_coef: 0.3779 - val_dice_coef_edema: 0.3347 - val_dice_coef_enhancing: 0.2777 - val_dice_coef_necrotic: 0.2666 - val_loss: 0.0464 - val_mean_io_u: 0.6416 - val_precision: 0.9911 - val_sensitivity: 0.9820 - val_specificity: 0.9969 - learning_rate: 3.0000e-04
# Epoch 6/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9835 - dice_coef: 0.3710 - dice_coef_edema: 0.3281 - dice_coef_enhancing: 0.2729 - dice_coef_necrotic: 0.3050 - loss: 0.0502 - mean_io_u: 0.6497 - precision: 0.9922 - sensitivity: 0.9785 - specificity: 0.9973
# Epoch 6: val_loss improved from 0.04639 to 0.04248, saving model to model_.06-0.042481.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9835 - dice_coef: 0.3709 - dice_coef_edema: 0.3280 - dice_coef_enhancing: 0.2727 - dice_coef_necrotic: 0.3049 - loss: 0.0502 - mean_io_u: 0.6494 - precision: 0.9922 - sensitivity: 0.9785 - specificity: 0.9973 - val_accuracy: 0.9848 - val_dice_coef: 0.3770 - val_dice_coef_edema: 0.3875 - val_dice_coef_enhancing: 0.3064 - val_dice_coef_necrotic: 0.3384 - val_loss: 0.0425 - val_mean_io_u: 0.6193 - val_precision: 0.9936 - val_sensitivity: 0.9806 - val_specificity: 0.9977 - learning_rate: 3.0000e-04
# Epoch 7/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9848 - dice_coef: 0.3858 - dice_coef_edema: 0.3683 - dice_coef_enhancing: 0.2988 - dice_coef_necrotic: 0.3353 - loss: 0.0430 - mean_io_u: 0.6581 - precision: 0.9931 - sensitivity: 0.9799 - specificity: 0.9975
# Epoch 7: val_loss improved from 0.04248 to 0.04005, saving model to model_.07-0.040052.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9849 - dice_coef: 0.3859 - dice_coef_edema: 0.3685 - dice_coef_enhancing: 0.2987 - dice_coef_necrotic: 0.3357 - loss: 0.0429 - mean_io_u: 0.6580 - precision: 0.9931 - sensitivity: 0.9799 - specificity: 0.9975 - val_accuracy: 0.9855 - val_dice_coef: 0.3965 - val_dice_coef_edema: 0.3906 - val_dice_coef_enhancing: 0.2859 - val_dice_coef_necrotic: 0.3023 - val_loss: 0.0401 - val_mean_io_u: 0.6192 - val_precision: 0.9922 - val_sensitivity: 0.9819 - val_specificity: 0.9973 - learning_rate: 3.0000e-04
# Epoch 8/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9855 - dice_coef: 0.3967 - dice_coef_edema: 0.3902 - dice_coef_enhancing: 0.2785 - dice_coef_necrotic: 0.3748 - loss: 0.0432 - mean_io_u: 0.6599 - precision: 0.9931 - sensitivity: 0.9800 - specificity: 0.9975
# Epoch 8: val_loss improved from 0.04005 to 0.03730, saving model to model_.08-0.037297.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9855 - dice_coef: 0.3968 - dice_coef_edema: 0.3905 - dice_coef_enhancing: 0.2788 - dice_coef_necrotic: 0.3751 - loss: 0.0431 - mean_io_u: 0.6600 - precision: 0.9931 - sensitivity: 0.9800 - specificity: 0.9975 - val_accuracy: 0.9862 - val_dice_coef: 0.4068 - val_dice_coef_edema: 0.4537 - val_dice_coef_enhancing: 0.3192 - val_dice_coef_necrotic: 0.3809 - val_loss: 0.0373 - val_mean_io_u: 0.6798 - val_precision: 0.9949 - val_sensitivity: 0.9802 - val_specificity: 0.9981 - learning_rate: 3.0000e-04
# Epoch 9/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9871 - dice_coef: 0.4166 - dice_coef_edema: 0.4518 - dice_coef_enhancing: 0.3075 - dice_coef_necrotic: 0.4029 - loss: 0.0360 - mean_io_u: 0.7153 - precision: 0.9941 - sensitivity: 0.9816 - specificity: 0.9979
# Epoch 9: val_loss did not improve from 0.03730
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9871 - dice_coef: 0.4165 - dice_coef_edema: 0.4516 - dice_coef_enhancing: 0.3075 - dice_coef_necrotic: 0.4029 - loss: 0.0360 - mean_io_u: 0.7151 - precision: 0.9941 - sensitivity: 0.9816 - specificity: 0.9979 - val_accuracy: 0.9856 - val_dice_coef: 0.3983 - val_dice_coef_edema: 0.3781 - val_dice_coef_enhancing: 0.2772 - val_dice_coef_necrotic: 0.2845 - val_loss: 0.0434 - val_mean_io_u: 0.6421 - val_precision: 0.9909 - val_sensitivity: 0.9825 - val_specificity: 0.9969 - learning_rate: 3.0000e-04
# Epoch 10/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9870 - dice_coef: 0.4295 - dice_coef_edema: 0.4813 - dice_coef_enhancing: 0.3337 - dice_coef_necrotic: 0.4128 - loss: 0.0352 - mean_io_u: 0.6811 - precision: 0.9943 - sensitivity: 0.9805 - specificity: 0.9979
# Epoch 10: val_loss improved from 0.03730 to 0.03512, saving model to model_.10-0.035124.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9870 - dice_coef: 0.4295 - dice_coef_edema: 0.4812 - dice_coef_enhancing: 0.3337 - dice_coef_necrotic: 0.4128 - loss: 0.0352 - mean_io_u: 0.6811 - precision: 0.9943 - sensitivity: 0.9805 - specificity: 0.9979 - val_accuracy: 0.9866 - val_dice_coef: 0.4270 - val_dice_coef_edema: 0.4437 - val_dice_coef_enhancing: 0.3669 - val_dice_coef_necrotic: 0.3631 - val_loss: 0.0351 - val_mean_io_u: 0.6939 - val_precision: 0.9928 - val_sensitivity: 0.9824 - val_specificity: 0.9975 - learning_rate: 3.0000e-04
# Epoch 11/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9874 - dice_coef: 0.4341 - dice_coef_edema: 0.4938 - dice_coef_enhancing: 0.3575 - dice_coef_necrotic: 0.4018 - loss: 0.0336 - mean_io_u: 0.7158 - precision: 0.9941 - sensitivity: 0.9817 - specificity: 0.9978
# Epoch 11: val_loss improved from 0.03512 to 0.03290, saving model to model_.11-0.032899.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.9874 - dice_coef: 0.4342 - dice_coef_edema: 0.4939 - dice_coef_enhancing: 0.3576 - dice_coef_necrotic: 0.4020 - loss: 0.0336 - mean_io_u: 0.7161 - precision: 0.9941 - sensitivity: 0.9817 - specificity: 0.9978 - val_accuracy: 0.9880 - val_dice_coef: 0.4427 - val_dice_coef_edema: 0.5155 - val_dice_coef_enhancing: 0.3911 - val_dice_coef_necrotic: 0.3961 - val_loss: 0.0329 - val_mean_io_u: 0.6941 - val_precision: 0.9948 - val_sensitivity: 0.9818 - val_specificity: 0.9980 - learning_rate: 3.0000e-04
# Epoch 12/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9873 - dice_coef: 0.4414 - dice_coef_edema: 0.4979 - dice_coef_enhancing: 0.3954 - dice_coef_necrotic: 0.4099 - loss: 0.0360 - mean_io_u: 0.6835 - precision: 0.9938 - sensitivity: 0.9813 - specificity: 0.9977
# Epoch 12: val_loss improved from 0.03290 to 0.03188, saving model to model_.12-0.031877.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.9873 - dice_coef: 0.4415 - dice_coef_edema: 0.4983 - dice_coef_enhancing: 0.3956 - dice_coef_necrotic: 0.4099 - loss: 0.0360 - mean_io_u: 0.6839 - precision: 0.9938 - sensitivity: 0.9813 - specificity: 0.9977 - val_accuracy: 0.9886 - val_dice_coef: 0.4438 - val_dice_coef_edema: 0.5587 - val_dice_coef_enhancing: 0.3977 - val_dice_coef_necrotic: 0.3939 - val_loss: 0.0319 - val_mean_io_u: 0.7240 - val_precision: 0.9943 - val_sensitivity: 0.9831 - val_specificity: 0.9979 - learning_rate: 3.0000e-04
# Epoch 13/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9885 - dice_coef: 0.4562 - dice_coef_edema: 0.5323 - dice_coef_enhancing: 0.4246 - dice_coef_necrotic: 0.4205 - loss: 0.0313 - mean_io_u: 0.7165 - precision: 0.9942 - sensitivity: 0.9830 - specificity: 0.9979
# Epoch 13: val_loss did not improve from 0.03188
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9885 - dice_coef: 0.4562 - dice_coef_edema: 0.5323 - dice_coef_enhancing: 0.4243 - dice_coef_necrotic: 0.4205 - loss: 0.0313 - mean_io_u: 0.7165 - precision: 0.9942 - sensitivity: 0.9830 - specificity: 0.9979 - val_accuracy: 0.9877 - val_dice_coef: 0.4405 - val_dice_coef_edema: 0.5326 - val_dice_coef_enhancing: 0.3328 - val_dice_coef_necrotic: 0.3037 - val_loss: 0.0356 - val_mean_io_u: 0.7534 - val_precision: 0.9915 - val_sensitivity: 0.9849 - val_specificity: 0.9971 - learning_rate: 3.0000e-04
# Epoch 14/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9887 - dice_coef: 0.4629 - dice_coef_edema: 0.5344 - dice_coef_enhancing: 0.4266 - dice_coef_necrotic: 0.4377 - loss: 0.0323 - mean_io_u: 0.7374 - precision: 0.9935 - sensitivity: 0.9839 - specificity: 0.9977
# Epoch 14: val_loss improved from 0.03188 to 0.03106, saving model to model_.14-0.031062.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9887 - dice_coef: 0.4629 - dice_coef_edema: 0.5347 - dice_coef_enhancing: 0.4266 - dice_coef_necrotic: 0.4377 - loss: 0.0323 - mean_io_u: 0.7372 - precision: 0.9935 - sensitivity: 0.9839 - specificity: 0.9977 - val_accuracy: 0.9886 - val_dice_coef: 0.4487 - val_dice_coef_edema: 0.5673 - val_dice_coef_enhancing: 0.3484 - val_dice_coef_necrotic: 0.3619 - val_loss: 0.0311 - val_mean_io_u: 0.5948 - val_precision: 0.9929 - val_sensitivity: 0.9852 - val_specificity: 0.9975 - learning_rate: 3.0000e-04
# Epoch 15/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9890 - dice_coef: 0.4684 - dice_coef_edema: 0.5631 - dice_coef_enhancing: 0.4044 - dice_coef_necrotic: 0.4488 - loss: 0.0313 - mean_io_u: 0.6530 - precision: 0.9937 - sensitivity: 0.9842 - specificity: 0.9978
# Epoch 15: val_loss improved from 0.03106 to 0.02987, saving model to model_.15-0.029869.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 130s 2s/step - accuracy: 0.9890 - dice_coef: 0.4684 - dice_coef_edema: 0.5631 - dice_coef_enhancing: 0.4049 - dice_coef_necrotic: 0.4487 - loss: 0.0313 - mean_io_u: 0.6533 - precision: 0.9937 - sensitivity: 0.9842 - specificity: 0.9978 - val_accuracy: 0.9895 - val_dice_coef: 0.4834 - val_dice_coef_edema: 0.6181 - val_dice_coef_enhancing: 0.4983 - val_dice_coef_necrotic: 0.3821 - val_loss: 0.0299 - val_mean_io_u: 0.6868 - val_precision: 0.9929 - val_sensitivity: 0.9855 - val_specificity: 0.9975 - learning_rate: 3.0000e-04
# Epoch 16/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9896 - dice_coef: 0.5001 - dice_coef_edema: 0.6258 - dice_coef_enhancing: 0.4975 - dice_coef_necrotic: 0.4673 - loss: 0.0277 - mean_io_u: 0.7074 - precision: 0.9932 - sensitivity: 0.9856 - specificity: 0.9976
# Epoch 16: val_loss improved from 0.02987 to 0.02966, saving model to model_.16-0.029660.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9896 - dice_coef: 0.5000 - dice_coef_edema: 0.6257 - dice_coef_enhancing: 0.4973 - dice_coef_necrotic: 0.4673 - loss: 0.0277 - mean_io_u: 0.7073 - precision: 0.9932 - sensitivity: 0.9857 - specificity: 0.9976 - val_accuracy: 0.9897 - val_dice_coef: 0.4753 - val_dice_coef_edema: 0.6197 - val_dice_coef_enhancing: 0.4613 - val_dice_coef_necrotic: 0.3467 - val_loss: 0.0297 - val_mean_io_u: 0.6828 - val_precision: 0.9924 - val_sensitivity: 0.9867 - val_specificity: 0.9974 - learning_rate: 3.0000e-04
# Epoch 17/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9903 - dice_coef: 0.4950 - dice_coef_edema: 0.6128 - dice_coef_enhancing: 0.4534 - dice_coef_necrotic: 0.4854 - loss: 0.0266 - mean_io_u: 0.7048 - precision: 0.9937 - sensitivity: 0.9862 - specificity: 0.9978
# Epoch 17: val_loss did not improve from 0.02966
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9903 - dice_coef: 0.4951 - dice_coef_edema: 0.6128 - dice_coef_enhancing: 0.4540 - dice_coef_necrotic: 0.4853 - loss: 0.0266 - mean_io_u: 0.7049 - precision: 0.9937 - sensitivity: 0.9862 - specificity: 0.9978 - val_accuracy: 0.9892 - val_dice_coef: 0.4716 - val_dice_coef_edema: 0.5932 - val_dice_coef_enhancing: 0.4806 - val_dice_coef_necrotic: 0.3440 - val_loss: 0.0304 - val_mean_io_u: 0.6868 - val_precision: 0.9925 - val_sensitivity: 0.9858 - val_specificity: 0.9974 - learning_rate: 3.0000e-04
# Epoch 18/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9901 - dice_coef: 0.5027 - dice_coef_edema: 0.6141 - dice_coef_enhancing: 0.5395 - dice_coef_necrotic: 0.4447 - loss: 0.0260 - mean_io_u: 0.7118 - precision: 0.9936 - sensitivity: 0.9862 - specificity: 0.9978
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
#
# Epoch 18: val_loss did not improve from 0.02966
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9902 - dice_coef: 0.5028 - dice_coef_edema: 0.6144 - dice_coef_enhancing: 0.5395 - dice_coef_necrotic: 0.4450 - loss: 0.0260 - mean_io_u: 0.7119 - precision: 0.9936 - sensitivity: 0.9862 - specificity: 0.9978 - val_accuracy: 0.9889 - val_dice_coef: 0.4809 - val_dice_coef_edema: 0.6014 - val_dice_coef_enhancing: 0.5261 - val_dice_coef_necrotic: 0.4563 - val_loss: 0.0327 - val_mean_io_u: 0.6872 - val_precision: 0.9934 - val_sensitivity: 0.9838 - val_specificity: 0.9977 - learning_rate: 3.0000e-04
# Epoch 19/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9895 - dice_coef: 0.5073 - dice_coef_edema: 0.5918 - dice_coef_enhancing: 0.5339 - dice_coef_necrotic: 0.5090 - loss: 0.0285 - mean_io_u: 0.7114 - precision: 0.9934 - sensitivity: 0.9852 - specificity: 0.9976
# Epoch 19: val_loss improved from 0.02966 to 0.02751, saving model to model_.19-0.027513.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9895 - dice_coef: 0.5074 - dice_coef_edema: 0.5922 - dice_coef_enhancing: 0.5339 - dice_coef_necrotic: 0.5088 - loss: 0.0285 - mean_io_u: 0.7115 - precision: 0.9934 - sensitivity: 0.9852 - specificity: 0.9976 - val_accuracy: 0.9900 - val_dice_coef: 0.5131 - val_dice_coef_edema: 0.6664 - val_dice_coef_enhancing: 0.4803 - val_dice_coef_necrotic: 0.4360 - val_loss: 0.0275 - val_mean_io_u: 0.7249 - val_precision: 0.9920 - val_sensitivity: 0.9878 - val_specificity: 0.9973 - learning_rate: 6.0000e-05
# Epoch 20/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9913 - dice_coef: 0.5406 - dice_coef_edema: 0.6783 - dice_coef_enhancing: 0.5615 - dice_coef_necrotic: 0.5301 - loss: 0.0236 - mean_io_u: 0.7271 - precision: 0.9934 - sensitivity: 0.9886 - specificity: 0.9977
# Epoch 20: val_loss did not improve from 0.02751
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9913 - dice_coef: 0.5406 - dice_coef_edema: 0.6782 - dice_coef_enhancing: 0.5613 - dice_coef_necrotic: 0.5304 - loss: 0.0236 - mean_io_u: 0.7271 - precision: 0.9934 - sensitivity: 0.9886 - specificity: 0.9977 - val_accuracy: 0.9901 - val_dice_coef: 0.5227 - val_dice_coef_edema: 0.6712 - val_dice_coef_enhancing: 0.5206 - val_dice_coef_necrotic: 0.4076 - val_loss: 0.0280 - val_mean_io_u: 0.7414 - val_precision: 0.9919 - val_sensitivity: 0.9880 - val_specificity: 0.9972 - learning_rate: 6.0000e-05
# Epoch 21/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9916 - dice_coef: 0.5514 - dice_coef_edema: 0.6936 - dice_coef_enhancing: 0.5936 - dice_coef_necrotic: 0.5102 - loss: 0.0228 - mean_io_u: 0.7425 - precision: 0.9934 - sensitivity: 0.9889 - specificity: 0.9977
# Epoch 21: val_loss improved from 0.02751 to 0.02674, saving model to model_.21-0.026744.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.9916 - dice_coef: 0.5513 - dice_coef_edema: 0.6934 - dice_coef_enhancing: 0.5935 - dice_coef_necrotic: 0.5105 - loss: 0.0228 - mean_io_u: 0.7425 - precision: 0.9934 - sensitivity: 0.9889 - specificity: 0.9977 - val_accuracy: 0.9905 - val_dice_coef: 0.5257 - val_dice_coef_edema: 0.6681 - val_dice_coef_enhancing: 0.5699 - val_dice_coef_necrotic: 0.4545 - val_loss: 0.0267 - val_mean_io_u: 0.7342 - val_precision: 0.9929 - val_sensitivity: 0.9876 - val_specificity: 0.9975 - learning_rate: 6.0000e-05
# Epoch 22/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9911 - dice_coef: 0.5513 - dice_coef_edema: 0.6710 - dice_coef_enhancing: 0.5748 - dice_coef_necrotic: 0.5640 - loss: 0.0234 - mean_io_u: 0.7486 - precision: 0.9934 - sensitivity: 0.9882 - specificity: 0.9977
# Epoch 22: val_loss did not improve from 0.02674
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.9911 - dice_coef: 0.5513 - dice_coef_edema: 0.6712 - dice_coef_enhancing: 0.5749 - dice_coef_necrotic: 0.5638 - loss: 0.0234 - mean_io_u: 0.7486 - precision: 0.9934 - sensitivity: 0.9882 - specificity: 0.9977 - val_accuracy: 0.9904 - val_dice_coef: 0.5354 - val_dice_coef_edema: 0.6799 - val_dice_coef_enhancing: 0.5503 - val_dice_coef_necrotic: 0.4679 - val_loss: 0.0268 - val_mean_io_u: 0.7369 - val_precision: 0.9921 - val_sensitivity: 0.9881 - val_specificity: 0.9973 - learning_rate: 6.0000e-05
# Epoch 23/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9920 - dice_coef: 0.5528 - dice_coef_edema: 0.6898 - dice_coef_enhancing: 0.5506 - dice_coef_necrotic: 0.5652 - loss: 0.0215 - mean_io_u: 0.7552 - precision: 0.9936 - sensitivity: 0.9896 - specificity: 0.9978
# Epoch 23: val_loss improved from 0.02674 to 0.02648, saving model to model_.23-0.026476.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.9920 - dice_coef: 0.5529 - dice_coef_edema: 0.6897 - dice_coef_enhancing: 0.5510 - dice_coef_necrotic: 0.5649 - loss: 0.0215 - mean_io_u: 0.7553 - precision: 0.9936 - sensitivity: 0.9896 - specificity: 0.9978 - val_accuracy: 0.9907 - val_dice_coef: 0.5258 - val_dice_coef_edema: 0.6545 - val_dice_coef_enhancing: 0.5598 - val_dice_coef_necrotic: 0.4524 - val_loss: 0.0265 - val_mean_io_u: 0.7482 - val_precision: 0.9929 - val_sensitivity: 0.9878 - val_specificity: 0.9976 - learning_rate: 6.0000e-05
# Epoch 24/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9908 - dice_coef: 0.5476 - dice_coef_edema: 0.6627 - dice_coef_enhancing: 0.5691 - dice_coef_necrotic: 0.5572 - loss: 0.0243 - mean_io_u: 0.7562 - precision: 0.9934 - sensitivity: 0.9876 - specificity: 0.9977
# Epoch 24: val_loss did not improve from 0.02648
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.9908 - dice_coef: 0.5477 - dice_coef_edema: 0.6630 - dice_coef_enhancing: 0.5695 - dice_coef_necrotic: 0.5570 - loss: 0.0243 - mean_io_u: 0.7562 - precision: 0.9934 - sensitivity: 0.9876 - specificity: 0.9977 - val_accuracy: 0.9905 - val_dice_coef: 0.5349 - val_dice_coef_edema: 0.6643 - val_dice_coef_enhancing: 0.5549 - val_dice_coef_necrotic: 0.4548 - val_loss: 0.0271 - val_mean_io_u: 0.7540 - val_precision: 0.9922 - val_sensitivity: 0.9882 - val_specificity: 0.9974 - learning_rate: 6.0000e-05
# Epoch 25/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9913 - dice_coef: 0.5540 - dice_coef_edema: 0.6929 - dice_coef_enhancing: 0.5676 - dice_coef_necrotic: 0.5512 - loss: 0.0236 - mean_io_u: 0.7521 - precision: 0.9933 - sensitivity: 0.9886 - specificity: 0.9977
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
#
# Epoch 25: val_loss did not improve from 0.02648
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.9913 - dice_coef: 0.5541 - dice_coef_edema: 0.6929 - dice_coef_enhancing: 0.5679 - dice_coef_necrotic: 0.5511 - loss: 0.0236 - mean_io_u: 0.7522 - precision: 0.9933 - sensitivity: 0.9886 - specificity: 0.9977 - val_accuracy: 0.9900 - val_dice_coef: 0.5193 - val_dice_coef_edema: 0.5825 - val_dice_coef_enhancing: 0.5470 - val_dice_coef_necrotic: 0.4899 - val_loss: 0.0280 - val_mean_io_u: 0.7696 - val_precision: 0.9930 - val_sensitivity: 0.9869 - val_specificity: 0.9976 - learning_rate: 6.0000e-05

# %% [markdown]
# ## **Load Trained Model**

# %%
model = keras.models.load_model(
    '/content/drive/MyDrive/Baseline_UNet/Baseline_UNet.keras',
    custom_objects={
        "accuracy": tf.keras.metrics.MeanIoU(num_classes=4),
        "dice_coef": DiceCoefMetric,
        "dice_coef_necrotic": DiceCoefNecroticMetric,
        "dice_coef_edema": DiceCoefEdemaMetric,
        "dice_coef_enhancing": DiceCoefEnhancingMetric,
        "precision": PrecisionMetric,
        "sensitivity": SensitivityMetric,
        "specificity": SpecificityMetric
    },
    compile=False
)

# %% [markdown]
# ## **Metrics Analysis**

# %%
history = pd.read_csv('/content/drive/MyDrive/Baseline_UNet/training.log', sep=',')

hist=history

acc=hist["accuracy"]
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Validation mean IOU')
ax[3].legend()

plt.savefig('training_plots.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
for f in os.listdir('/content'):
    if f.endswith('.weights.h5'):
        print(f)
# Out:
# model_.11-0.032899.weights.h5
# model_.02-0.070187.weights.h5
# model_.16-0.029660.weights.h5
# model_.12-0.031877.weights.h5
# model_.05-0.046387.weights.h5
# model_.23-0.026476.weights.h5
# model_.19-0.027513.weights.h5
# model_.04-0.059736.weights.h5
# model_.03-0.065467.weights.h5
# model_.08-0.037297.weights.h5
# model_.21-0.026744.weights.h5
# model_.07-0.040052.weights.h5
# model_.14-0.031062.weights.h5
# model_.15-0.029869.weights.h5
# model_.10-0.035124.weights.h5
# model_.01-0.075444.weights.h5
# model_.06-0.042481.weights.h5

# %%
def imageLoader(path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
    return np.array(image)

def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] )
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])

    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')

def predictByPath(case_path, case):
    # Create input array for 4 modalities
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 4))

    # Load each modality
    t1_path = os.path.join(case_path, f'{case}_t1.nii')
    t1ce_path  = os.path.join(case_path, f'{case}_t1ce.nii')
    t2_path    = os.path.join(case_path, f'{case}_t2.nii')
    flair_path = os.path.join(case_path, f'{case}_flair.nii')

    t1    = nib.load(t1_path).get_fdata()
    t1ce  = nib.load(t1ce_path).get_fdata()
    t2    = nib.load(t2_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    for j in range(VOLUME_SLICES):
        slice_index = j + VOLUME_START_AT
        X[j, :, :, 0] = cv2.resize(t1[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 1] = cv2.resize(t1ce[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 2] = cv2.resize(t2[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 3] = cv2.resize(flair[:, :, slice_index], (IMG_SIZE, IMG_SIZE))

    # Normalize the input before prediction
    X_norm = X / np.max(X)
    return model.predict(X_norm, verbose=1)

def showPredictsById(case, start_slice=60):
    path = f"/content/drive/MyDrive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/{case}"

    # Load ground truth segmentation
    gt = nib.load(os.path.join(path, f'{case}_seg.nii')).get_fdata()

    # Load all four modalities
    t1 = nib.load(os.path.join(path, f'{case}_t1.nii')).get_fdata()
    t1ce  = nib.load(os.path.join(path, f'{case}_t1ce.nii')).get_fdata()
    t2    = nib.load(os.path.join(path, f'{case}_t2.nii')).get_fdata()
    flair = nib.load(os.path.join(path, f'{case}_flair.nii')).get_fdata()

    # Get predicted segmentation from your predictByPath function
    p = predictByPath(path, case)

    # Extract predicted segmentation channels
    core = p[:,:,:,1]
    edema = p[:,:,:,2]
    enhancing = p[:,:,:,3]

    # Determine slice indices
    slice_idx = start_slice + VOLUME_START_AT  # for the original modalities and GT
    # For predictions, we assume p has VOLUME_SLICES slices; here we use start_slice index.

    # Create a figure with 2 rows and 5 columns
    fig, axs = plt.subplots(2, 5, figsize=(25, 10))

    # Row 0: Original modalities
    axs[0, 0].imshow(cv2.resize(t1[:, :, slice_idx], (IMG_SIZE, IMG_SIZE)), cmap='gray', interpolation='none')
    axs[0, 0].set_title('Original T1')

    axs[0, 1].imshow(cv2.resize(t1ce[:, :, slice_idx], (IMG_SIZE, IMG_SIZE)), cmap='gray', interpolation='none')
    axs[0, 1].set_title('Original T1ce')

    axs[0, 2].imshow(cv2.resize(t2[:, :, slice_idx], (IMG_SIZE, IMG_SIZE)), cmap='gray', interpolation='none')
    axs[0, 2].set_title('Original T2')

    axs[0, 3].imshow(cv2.resize(flair[:, :, slice_idx], (IMG_SIZE, IMG_SIZE)), cmap='gray', interpolation='none')
    axs[0, 3].set_title('Original FLAIR')

    # Leave the 5th subplot empty or use it for a montage if desired.
    axs[0, 4].axis('off')

    # Row 1: Ground truth and predictions
    curr_gt = cv2.resize(gt[:, :, slice_idx], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)
    axs[1, 0].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.5)
    axs[1, 0].set_title('Ground Truth')

    # For aggregated predicted segmentation, you can show the argmax across channels.
    pred_seg = np.argmax(p, axis=-1)
    pred_seg_slice = cv2.resize(pred_seg[start_slice, :, :], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)
    axs[1, 1].imshow(pred_seg_slice, cmap="jet", interpolation='none', alpha=0.5)
    axs[1, 1].set_title('Predicted Segmentation')

    axs[1, 2].imshow(cv2.resize(edema[start_slice, :, :], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST), cmap="OrRd", alpha=0.5)
    axs[1, 2].set_title(f'{SEGMENT_CLASSES[1]} predicted')

    axs[1, 3].imshow(cv2.resize(core[start_slice, :, :], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST), cmap="OrRd", alpha=0.5)
    axs[1, 3].set_title(f'{SEGMENT_CLASSES[2]} predicted')

    axs[1, 4].imshow(cv2.resize(enhancing[start_slice, :, :], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST), cmap="OrRd", alpha=0.5)
    axs[1, 4].set_title(f'{SEGMENT_CLASSES[3]} predicted')

    plt.tight_layout()
    plt.savefig('all_modalities_slice_sample.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
showPredictsById(case=test_ids[10])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 556ms/step

# %%
# Evaluate the model on the test data
model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.0003),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        DiceCoefMetric(),
        PrecisionMetric(),
        SensitivityMetric(),
        SpecificityMetric(),
        DiceCoefNecroticMetric(),
        DiceCoefEdemaMetric(),
        DiceCoefEnhancingMetric()
    ]
)

# Evaluate the model on the test data
results = model.evaluate(test_generator, batch_size=100, callbacks=callbacks)

descriptions = [
    "Loss", "Accuracy", "MeanIOU", "Dice coefficient",
    "Precision", "Sensitivity", "Specificity",
    "Dice coef Necrotic", "Dice coef Edema", "Dice coef Enhancing"
]

# Combine results
print("\nModel evaluation on the test set:")
print("==================================")
for metric, description in zip(results, descriptions):
    print(f"{description} : {round(metric, 4)}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 115s 11s/step - accuracy: 0.9890 - dice_coef: 0.5381 - dice_coef_edema: 0.5917 - dice_coef_enhancing: 0.6325 - dice_coef_necrotic: 0.4564 - loss: 0.0340 - mean_io_u_3: 0.7531 - precision: 0.9918 - sensitivity: 0.9859 - specificity: 0.9972
#
# Model evaluation on the test set:
# ==================================
# Loss : 0.0325
# Accuracy : 0.9884
# MeanIOU : 0.7648
# Dice coefficient : 0.5248
# Precision : 0.9915
# Sensitivity : 0.985
# Specificity : 0.9971
# Dice coef Necrotic : 0.4895
# Dice coef Edema : 0.5968
# Dice coef Enhancing : 0.5289

# %%
import csv

# Save training subject ids
with open('/content/drive/MyDrive/Baseline_UNet/train_subjects.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Subject ID'])
    for subject in train_ids:
        writer.writerow([subject])

# Save validation subject ids
with open('/content/drive/MyDrive/Baseline_UNet/validation_subjects.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Subject ID'])
    for subject in val_ids:
        writer.writerow([subject])

# Save test subject ids
with open('/content/drive/MyDrive/Baseline_UNet/test_subjects.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Subject ID'])
    for subject in test_ids:
        writer.writerow([subject])

# For training generator
with open('/content/drive/MyDrive/Baseline_UNet/train_batches.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Batch Index', 'Subject IDs'])
    for i in range(len(training_generator)):
        batch_indices = training_generator.indexes[i * training_generator.batch_size:(i+1) * training_generator.batch_size]
        batch_ids = [training_generator.list_IDs[idx] for idx in batch_indices]
        writer.writerow([i, ','.join(batch_ids)])

# For validation generator
with open('/content/drive/MyDrive/Baseline_UNet/validation_batches.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Batch Index', 'Subject IDs'])
    for i in range(len(valid_generator)):
        batch_indices = valid_generator.indexes[i * valid_generator.batch_size:(i+1) * valid_generator.batch_size]
        batch_ids = [valid_generator.list_IDs[idx] for idx in batch_indices]
        writer.writerow([i, ','.join(batch_ids)])

# For test generator
with open('/content/drive/MyDrive/Baseline_UNet/test_batches.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Batch Index', 'Subject IDs'])
    for i in range(len(test_generator)):
        batch_indices = test_generator.indexes[i * test_generator.batch_size:(i+1) * test_generator.batch_size]
        batch_ids = [test_generator.list_IDs[idx] for idx in batch_indices]
        writer.writerow([i, ','.join(batch_ids)])
