# %% [markdown]
# ## **Dataset Information**
# The Brain Tumor Segmentation (BraTS) 2020 dataset is a collection of multimodal Magnetic Resonance Imaging (MRI) scans used for the segmentation of brain tumors.
#
# It includes MRI scans from glioma patients, providing four different MRI modalities (means 4 channels of information - 4 different volumes of the same region) per patient:
#
# 1. **Native (T1)**
# 2. **Post-contrast T1-weighted (T1ce - contrast enhanced)**
# 3. **T2-weighted (T2)**
# 4. **T2-FLAIR (T2 - Fluied Attenuated Inversion Recovery)**
#
# These scans come with expert-annotated segmentation masks that delineate the tumor into various sub-regions, such as the necrotic and non-enhancing tumor core, the peritumoral edema, and the enhancing tumor.
#
# Annotations (labels):
# 1. **Label 0:** Not Tumor (NT) volume
# 2. **Label 1:** Necrotic and non-enhancing tumor core (NCR/NET)
# 3. **Label 2:** Peritumoral edema (ED)
# 4. **Label 3:** Missing (No pixels in all the volumes contain label 3)
# 5. **Label 4:** GD-enhancing tumor (ET)
#
# As there are no pixels with the label 3, we will be replacing label 3 with label 4 so that there is continuity between the labels.
#
# Inside the ``brats20-dataset-training-validation`` folder, there are two datasets: one for training and one for validation. The ``BraTS2020_TrainingData`` folder contains another folder with 369 samples (which are patients here).

# %% [markdown]
# ## **Load and Explore Dataset**

# %%
import os
import cv2
import random
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nibabel as nib
import keras
import tensorflow.keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard

# %%
# Create the distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %%
Train_Path = "/kaggle/input/mlma-project/BraTS2020_TrainingData/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/"

# %%
old_name = Train_Path + "BraTS20_Training_355/W39_1998.09.19_Segm.nii"
new_name = Train_Path + "BraTS20_Training_355/BraTS20_Training_355_seg.nii"

# renaming the file
try:
    os.rename(old_name, new_name)
    print("File has been re-named successfully!")
except:
    print("File is already renamed!")
# Out:
# File is already renamed!

# %%
# load .nii file as a numpy array
test_image_flair = nib.load(Train_Path + "BraTS20_Training_306/BraTS20_Training_306_flair.nii").get_fdata()
print("Shape: ", test_image_flair.shape)
print("Dtype: ", test_image_flair.dtype)
# Out:
# Shape:  (240, 240, 155)
# Dtype:  float64

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1116.0

# %%
scaler = MinMaxScaler()
test_image_flair = scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# rescaling t1
test_image_t1 = nib.load(Train_Path + 'BraTS20_Training_306/BraTS20_Training_306_t1.nii').get_fdata()
test_image_t1 = scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

# rescaling t1ce
test_image_t1ce = nib.load(Train_Path + 'BraTS20_Training_306/BraTS20_Training_306_t1ce.nii').get_fdata()
test_image_t1ce = scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

# rescaling t2
test_image_t2 = nib.load(Train_Path + 'BraTS20_Training_306/BraTS20_Training_306_t2.nii').get_fdata()
test_image_t2 = scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

# we will not rescale the mask
test_image_seg = nib.load(Train_Path + 'BraTS20_Training_306/BraTS20_Training_306_seg.nii').get_fdata()

# %%
slice = 95

print("Slice Number: " + str(slice))

plt.figure(figsize=(12, 8))

# T1
plt.subplot(2, 3, 1)
plt.imshow(test_image_t1[:,:,slice], cmap='gray')
plt.title('T1')

# T1ce
plt.subplot(2, 3, 2)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1ce')

# T2
plt.subplot(2, 3, 3)
plt.imshow(test_image_t2[:,:,slice], cmap='gray')
plt.title('T2')

# Flair
plt.subplot(2, 3, 4)
plt.imshow(test_image_flair[:,:,slice], cmap='gray')
plt.title('FLAIR')

# Mask
plt.subplot(2, 3, 5)
plt.imshow(test_image_seg[:,:,slice])
plt.title('Mask')
plt.show()
# Out:
# Slice Number: 95

# %% [markdown]
# The four imaging modalities provide distinct perspectives on the same brain image, each highlighting different features.
#
# **Detailed Description of Each Modality:**
# 1. **Native (T1):** This modality reveals the structure and composition of various tissue types in the brain. It's instrumental in identifying tumors, cysts, and other abnormalities.
# 2. **Post-contrast T1-weighted (T1ce, also known as T1Gd):** Similar to T1 images, but enhanced with a contrast agent (Gadolinium), which improves the visibility of abnormalities.
# 3. **T2-weighted (T2):** This modality highlights the fluid content within brain tissues.
# 4. **T2-FLAIR (T2 - Fluid Attenuated Inversion Recovery):** This technique suppresses the fluid signals, making it easier to identify lesions that may not be visible on T1 or T2 images. It is particularly useful for detecting lesions in the brain's white matter, which are challenging to spot with other scans.
#
# For medical experts, these four modalities collectively provide a comprehensive view, aiding in precise tumor analysis and confirmation. However, in our artificial intelligence approach, we aim to streamline the process by reducing computational and memory demands. Utilizing only two modalities can achieve this, making the segmentation task faster and more efficient.
#
# To optimize our model, we will exclude the T1 modality since its enhanced counterpart, **T1ce**, provides better clarity. Similarly, we will omit the T2 modality because the fluids it highlights could negatively impact our predictions. Instead, the **T2-FLAIR** modality, which effectively highlights affected regions by suppressing fluid signals, will be more beneficial for our training.

# %%
# Modality shape
print("Modality: ", test_image_t1.shape)

# Segmentation shape
print("Segmentation: ", test_image_seg.shape)
# Out:
# Modality:  (240, 240, 155)
# Segmentation:  (240, 240, 155)

# %% [markdown]
# As we can see, the modalities and segmentations have 3 dimensions. Each dimension consists of a series of two-dimensional images, known as slices, which all contain the same number of pixels and are stacked together to create this 3D representation. For instance, in our previous example, we displayed the 95th slice of a certain dimension.
#
# These 3 dimensions correspond to the three spatial dimensions of the image: width, height, and depth. In medical imaging, these dimensions are referred to as the axial (transverse), coronal, and sagittal planes, corresponding to the three main orientations of the human body and, therefore, the human brain.
#
# Here is a quick presentation of these 3 planes:
# 1. **Axial (Transverse) Plane:** This plane divides the body into upper and lower parts and is perpendicular to the long axis of the body. In brain imaging, an axial slice is a horizontal cut through the brain.
# 2. **Coronal (Frontal) Plane:** This plane divides the body into front (anterior) and back (posterior) parts. A coronal slice in brain imaging is a vertical cut from one side of the head to the other, dividing the brain into front and back sections.
# 3. **Sagittal (Lateral) Plane:** This plane divides the body into left and right parts. A sagittal slice in brain imaging is a vertical cut from front to back, dividing the brain into left and right sections.
#
# Understanding these planes is crucial for accurately interpreting medical images and effectively utilizing them in segmentation tasks. Each plane provides a different perspective, helping to localize and identify anatomical structures and abnormalities.

# %%
slice = 95

print("Slice number: " + str(slice))

plt.figure(figsize=(12, 8))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
# T1 - Transverse View
plt.subplot(1, 3, 1)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1 - Transverse View')

# T1 - Frontal View
plt.subplot(1, 3, 2)
plt.imshow(rotate(test_image_t1ce[:,slice,:], 90, resize=True), cmap='gray')
plt.title('T1 - Frontal View')

# T1 - Sagittal View
plt.subplot(1, 3, 3)
plt.imshow(rotate(test_image_t1ce[slice,:,:], 90, resize=True), cmap='gray')
plt.title('T1 - Sagittal View')
plt.show()
# Out:
# Slice number: 95

# %%
# montage allows us to concatenate multiple images of the same size horizontally and vertically
plt.imshow(rotate(montage(test_image_t1ce[:,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.imshow(rotate(montage(test_image_t1ce[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.imshow(rotate(montage(test_image_seg[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %% [markdown]
# Now, let's focus on the segmentations provided by the experts. These segmentations provide critical information about the tumor:
#
# 1. **Location:** Identifies the exact location of the tumor in the brain.
# 2. **Size and Shape:** Measures the tumor's dimensions and form.
# 3. **Type:** Helps differentiate between various tumor types.
# 4. **Heterogeneity:** Reveals different components within the tumor (e.g., solid tissue, necrotic areas).
# 5. **Surrounding Tissue Involvement:** Shows how the tumor interacts with adjacent brain structures.
# 6. **Cross-Modality Comparison:** Provides a comprehensive view by comparing different imaging modalities.

# %%
# Plotting the segmantation
cmap = matplotlib.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = matplotlib.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# plotting the 95th slice
plt.imshow(test_image_seg[:,:,95], cmap=cmap, norm=norm)
plt.colorbar()
plt.show()

# %%
# Isolation of class 0
seg_0 = test_image_seg.copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = test_image_seg.copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = test_image_seg.copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_4 = test_image_seg.copy()
seg_4[seg_4 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 4']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, ax = plt.subplots(1, 5, figsize=(20, 20))

ax[0].imshow(test_image_seg[:,:, slice], cmap=cmap, norm=norm)
ax[0].set_title('Original Segmentation')
ax[0].legend(handles=legend, loc='lower left')

ax[1].imshow(seg_0[:,:, slice], cmap=cmap, norm=norm)
ax[1].set_title('Not Tumor (class 0)')

ax[2].imshow(seg_1[:,:, slice], cmap=cmap, norm=norm)
ax[2].set_title('Non-Enhancing Tumor (class 1)')

ax[3].imshow(seg_2[:,:, slice], cmap=cmap, norm=norm)
ax[3].set_title('Edema (class 2)')

ax[4].imshow(seg_4[:,:, slice], cmap=cmap, norm=norm)
ax[4].set_title('Enhancing Tumor (class 4)')

plt.show()

# %% [markdown]
# To summarize our data exploration:
# * **Modalities:** Each sample/patient has 4 different modalities (T1, T1CE, T2, and FLAIR), accompanied by a segmentation indicating tumor areas.
# * **Selected Modalities:** We will focus on T1CE and FLAIR as they provide complementary information about the brain's anatomy and tissue contrast.
# * **3D Images:** Each image is 3D and can be analyzed through 3 different planes composed of 2D slices.
# * **Informative Slices:** Many slices contain little or no information. We will use slices in the (50:-50) interval. You can customize this range, but note that changing it may affect training time.
# * **Segmentation Classes:** Segmentation images contain 1 to 4 classes. Class 4 will be reassigned to 3 since class 3 is missing.
# * **Background Class:** Class 0 (background) is over-represented. Cropping might remove important information, so we will keep the images as they are.
#
# Now that we understand our data better, it's time to prepare for model training.

# %% [markdown]
# ## **Splitting the Data**
#
# * **Training Set:** 70-80%
# * **Validation Set:** 10-15%
# * **Testing Set:** 10-15%
#
# We can use random splitting with stratification.

# %%
train_and_val_directories = [f.path for f in os.scandir(Train_Path) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories)

# First, split into 70% training and 30% temporary set
train_ids, temp_ids = train_test_split(train_and_test_ids, test_size=0.30, random_state=42)

# Then, split the temporary set equally into 15% validation and 15% testing
val_ids, test_ids = train_test_split(temp_ids, test_size=0.5, random_state=42)

print(f"Train length: {len(train_ids)}")
print(f"Validation length: {len(val_ids)}")
print(f"Test length: {len(test_ids)}")
# Out:
# Train length: 258
# Validation length: 55
# Test length: 56

# %%
plt.bar(["Train","Valid","Test"],
        [len(train_ids), len(val_ids), len(test_ids)],
        align='center',
        color=[ 'green','red', 'blue'],
        label=["Train", "Valid", "Test"]
       )

plt.legend()

plt.ylabel('Number of Images')
plt.title('Data Distribution')

plt.show()

# %% [markdown]
# ## **DataGenerator**
# To train a neural network for image segmentation, we need both raw image data (X) and ground truth segmentations (y). This allows the network to learn tumor patterns and make accurate predictions from patient scans. However, directly loading all 3D images can overload system memory and cause shape mismatch errors. Therefore, we use a Data Generator for image preprocessing, which includes several steps:
# 1. **Retrieve paths:** Obtain the paths for the T1CE and FLAIR modalities (for complementary anatomical and tissue contrast information) and the ground truth segmentation.
# 2. **Load data:** Load the selected slices (60-135) from these modalities and the corresponding segmentation.
# 3. **Create arrays:** Form X arrays with the slices from T1CE and FLAIR, and y arrays with the segmentation slices.
# 4. **Class reassignment:** Assign a value of 3 to all instances of 4 in the mask array to correct the missing class issue.
#
# Additional preprocessing steps include:
# * **Axial plane:** Use the axial plane for its square shape (240x240). This enables visualizing predictions across all planes without impact.
# * **One-Hot Encoding:** Apply One-Hot Encoding to the y array to convert classes (0 to 3) into a numerical format suitable for neural networks, avoiding any implied hierarchy between classes.
# * **Resize images:** Resize each slice from (240x240) to (128x128). This shape is chosen because it is a power of two, fitting well with pooling layers (MaxPooling2D) in CNNs, and balances computational efficiency and information preservation.
#
# While resizing to (256x256) could retain more detail, it significantly increases training time and memory usage. We can choose to train with (256x256) images, but we’ll need to adjust your U-Net architecture accordingly.
#
# Now that we have a clear understanding of our data and preprocessing steps, we can proceed to prepare our model for training.

# %%
# Define seg-areas
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3
}

# Select Slices and Image Size
VOLUME_SLICES = 100
VOLUME_START_AT = 22 # first slice of volume that we will include
IMG_SIZE=128

# %%
class DataGenerator(keras.utils.Sequence):
    """Generates data for Keras."""
    def __init__(self, list_IDs, dim=(IMG_SIZE, IMG_SIZE), batch_size=4, n_channels=4, shuffle=True, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        "Denotes the number of batches per epoch (using ceil to include the last partial batch)"
        return int(np.ceil(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        "Generate one batch of data"
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        Batch_ids = [self.list_IDs[k] for k in indexes]
        X, Y = self.__data_generation(Batch_ids)
        #print("Batch max value:", np.max(X))
        return X, Y

    def on_epoch_end(self):
        "Updates indexes after each epoch"
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        "Generates data containing batch_size samples"
        batch_size_actual = len(Batch_ids)
        # Initialize X to hold each slice for each case
        X = np.zeros((batch_size_actual * VOLUME_SLICES, *self.dim, self.n_channels), dtype=np.float32)
        # y is initially defined with shape (batch_size * VOLUME_SLICES, 240, 240)
        y = np.zeros((batch_size_actual * VOLUME_SLICES, 240, 240), dtype=np.int32)

        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(Train_Path, i)

            t1 = nib.load(os.path.join(case_path, f'{i}_t1.nii')).get_fdata()
            t2 = nib.load(os.path.join(case_path, f'{i}_t2.nii')).get_fdata()
            flair = nib.load(os.path.join(case_path, f'{i}_flair.nii')).get_fdata()
            t1ce = nib.load(os.path.join(case_path, f'{i}_t1ce.nii')).get_fdata()
            seg = nib.load(os.path.join(case_path, f'{i}_seg.nii')).get_fdata()

            for j in range(VOLUME_SLICES):
                slice_index = j + VOLUME_START_AT
                # Rezise T1 and T2
                X[j + VOLUME_SLICES * c, :, :, 0] = cv2.resize(t1[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
                X[j + VOLUME_SLICES * c, :, :, 2] = cv2.resize(t2[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
                # Resize the flair and t1ce images to (IMG_SIZE, IMG_SIZE)
                X[j + VOLUME_SLICES * c, :, :, 1] = cv2.resize(flair[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
                X[j + VOLUME_SLICES * c, :, :, 3] = cv2.resize(t1ce[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
                # Resize the segmentation to 240x240 (if needed)
                y[j + VOLUME_SLICES * c] = cv2.resize(seg[:, :, slice_index], (240, 240))

        # Replace label 4 with 3 in the segmentation
        y[y == 4] = 3
        # Convert y to one-hot encoding with 4 classes
        mask = tf.one_hot(y, 4)
        # Resize mask to (IMG_SIZE, IMG_SIZE) for each slice
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # Normalize X safely (avoid division by zero)
        max_val = np.max(X)
        if max_val != 0:
            X = X / max_val
        return X, Y

# Usage:
training_generator = DataGenerator(train_ids, batch_size=4, n_channels=4)
valid_generator = DataGenerator(val_ids, batch_size=4, n_channels=4)
test_generator = DataGenerator(test_ids, batch_size=4, n_channels=4)

# %% [markdown]
# ### **Preprocessing Steps Summary**
# **Data Generator:** Utilized to process and send data to the neural network without overloading memory.
# **Epoch Handling:** For each epoch, the model processes 250 samples from the training dataset.
# **Sample Analysis:** Each sample consists of 150 slices (100 slices each from two modalities) resized to (128, 128).
# **Data Shapes:**
# * **X Array:** Shape (128, 128, 100, 2) for input images.
# * **Ground Truth (y):** One-Hot encoded segmentation with shape (100, 128, 128, 4).
#
# This preprocessing setup ensures efficient data handling and preparation for training the neural network.

# %%
# Define a function to display one slice and its segmentation
def display_slice_and_segmentation(flair, t1ce, segmentation):
    fig, axes = plt.subplots(1, 3, figsize=(10, 5))

    axes[0].imshow(flair, cmap='gray')
    axes[0].set_title('Flair')
    axes[0].axis('off')

    axes[1].imshow(t1ce, cmap='gray')
    axes[1].set_title('T1CE')
    axes[1].axis('off')

    axes[2].imshow(segmentation) # Displaying segmentation
    axes[2].set_title('Segmentation')
    axes[2].axis('off')

    plt.tight_layout()
    plt.show()


# Retrieve the batch from the training generator
X_batch, Y_batch = training_generator[8]

# Extract Flair, T1CE, and segmentation from the batch
flair_batch = X_batch[:, :, :, 0]
t1ce_batch = X_batch[:, :, :, 1]
segmentation_batch = np.argmax(Y_batch, axis=-1)  # Convert one-hot encoded to categorical

# Extract the 50th slice from Flair, T1CE, and segmentation
slice_index = 60  # Indexing starts from 0
slice_flair = flair_batch[slice_index]
slice_t1ce = t1ce_batch[slice_index]
slice_segmentation = segmentation_batch[slice_index]

# Display the 50th slice and its segmentation
display_slice_and_segmentation(slice_flair, slice_t1ce, slice_segmentation)

# %% [markdown]
# ## **Loss Function and Evaluation Metrics**
#
# **Loss Function**
#
# When training a CNN, selecting an appropriate loss function is crucial for accurately reflecting the network's performance. This function compares the predicted pixels to the ground truth for each patient, guiding the model to update its weights to minimize the loss and improve prediction accuracy.
#
# For multi-class classification problems, a commonly used loss function is categorical cross-entropy. This function measures the difference between the predicted probability distribution of each pixel and the one-hot encoded ground truth values. Additionally, segmentation models sometimes use the Dice loss function, which focuses on the overlap between the predicted and actual segments, further refining the accuracy of the segmentation.
#
# Using these loss functions helps ensure that the model learns effectively and produces accurate segmentations of brain tumors.

# %%
# 1. DiceCoefMetric (for all classes)
# 1. DiceCoefMetric (for all classes)
class DiceCoefMetric(tf.keras.metrics.Metric):
    def __init__(self, num_classes=4, smooth=1.0, name='dice_coef', **kwargs):
        super(DiceCoefMetric, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.smooth = smooth
        self.total_dice = self.add_weight(name='total_dice', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')
        
    def update_state(self, y_true, y_pred, sample_weight=None):
        dice_sum = 0.0
        for i in range(self.num_classes):
            y_true_f = tf.reshape(y_true[..., i], [-1])
            y_pred_f = tf.reshape(y_pred[..., i], [-1])
            intersection = tf.reduce_sum(y_true_f * y_pred_f)
            dice = (2. * intersection + self.smooth) / (
                tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + self.smooth)
            dice_sum += dice
        dice_avg = dice_sum / self.num_classes
        self.total_dice.assign_add(dice_avg)
        self.count.assign_add(1.0)
        
    def result(self):
        return self.total_dice / self.count
    
    def reset_states(self):
        self.total_dice.assign(0.0)
        self.count.assign(0.0)

# %% [markdown]
# ### **Per Class Dice Coefficient Functions**
# These functions calculate the Dice coefficient for specific tumor classes in segmentation tasks, helping to measure the model's performance in predicting different tumor regions:
#
# * **dice_coef_necrotic:** Calculates the Dice coefficient for the necrotic (dead tissue) tumor region. It computes the intersection over the sum of squares of the true and predicted values for the necrotic class.
# * **dice_coef_edema:** Calculates the Dice coefficient for the edema (swelling) tumor region. It computes the intersection over the sum of squares of the true and predicted values for the edema class.
# * **dice_coef_enhancing:** Calculates the Dice coefficient for the enhancing tumor region. It computes the intersection over the sum of squares of the true and predicted values for the enhancing class.

# %%
# 2. DiceCoefNecroticMetric (for channel index 1)
class DiceCoefNecroticMetric(tf.keras.metrics.Metric):
    def __init__(self, smooth=1e-6, name='dice_coef_necrotic', **kwargs):
        super(DiceCoefNecroticMetric, self).__init__(name=name, **kwargs)
        self.smooth = smooth
        self.total_dice = self.add_weight(name='total_dice_necrotic', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')
        
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_channel = tf.reshape(y_true[..., 1], [-1])
        y_pred_channel = tf.reshape(y_pred[..., 1], [-1])
        intersection = tf.reduce_sum(tf.abs(y_true_channel * y_pred_channel))
        dice = (2. * intersection) / (
            tf.reduce_sum(tf.square(y_true_channel)) + tf.reduce_sum(tf.square(y_pred_channel)) + self.smooth)
        self.total_dice.assign_add(dice)
        self.count.assign_add(1.0)
        
    def result(self):
        return self.total_dice / self.count
    
    def reset_states(self):
        self.total_dice.assign(0.0)
        self.count.assign(0.0)

# 3. DiceCoefEdemaMetric (for channel index 2)
class DiceCoefEdemaMetric(tf.keras.metrics.Metric):
    def __init__(self, smooth=1e-6, name='dice_coef_edema', **kwargs):
        super(DiceCoefEdemaMetric, self).__init__(name=name, **kwargs)
        self.smooth = smooth
        self.total_dice = self.add_weight(name='total_dice_edema', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_channel = tf.reshape(y_true[..., 2], [-1])
        y_pred_channel = tf.reshape(y_pred[..., 2], [-1])
        intersection = tf.reduce_sum(y_true_channel * y_pred_channel)
        dice = (2. * intersection) / (
            tf.reduce_sum(tf.square(y_true_channel)) + tf.reduce_sum(tf.square(y_pred_channel)) + self.smooth)
        self.total_dice.assign_add(dice)
        self.count.assign_add(1.0)
        
    def result(self):
        return self.total_dice / self.count
    
    def reset_states(self):
        self.total_dice.assign(0.0)
        self.count.assign(0.0)

# 4. DiceCoefEnhancingMetric (for channel index 3)
class DiceCoefEnhancingMetric(tf.keras.metrics.Metric):
    def __init__(self, smooth=1e-6, name='dice_coef_enhancing', **kwargs):
        super(DiceCoefEnhancingMetric, self).__init__(name=name, **kwargs)
        self.smooth = smooth
        self.total_dice = self.add_weight(name='total_dice_enhancing', initializer='zeros')
        self.count = self.add_weight(name='count', initializer='zeros')
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_channel = tf.reshape(y_true[..., 3], [-1])
        y_pred_channel = tf.reshape(y_pred[..., 3], [-1])
        intersection = tf.reduce_sum(tf.abs(y_true_channel * y_pred_channel))
        dice = (2. * intersection) / (
            tf.reduce_sum(tf.square(y_true_channel)) + tf.reduce_sum(tf.square(y_pred_channel)) + self.smooth)
        self.total_dice.assign_add(dice)
        self.count.assign_add(1.0)
    
    def result(self):
        return self.total_dice / self.count
    
    def reset_states(self):
        self.total_dice.assign(0.0)
        self.count.assign(0.0)

# %% [markdown]
# ### **Evaluation Metrics**
# To effectively monitor the model's performance, we use various evaluation metrics:
#
# * **Accuracy:** Measures the overall proportion of correctly classified pixels. However, it can be misleading with imbalanced datasets like BraTS2020, where the background class is overrepresented.
# * **Intersection over Union (IoU):** Measures the overlap between the predicted and ground truth segmentations.
# * **Dice Coefficient:** Evaluates the similarity between predicted and ground truth segmentations.
# * **Sensitivity (Recall or True Positive Rate):** Measures the proportion of positive ground truth pixels correctly predicted as positive.
# * **Precision (Positive Predictive Value):** Measures the proportion of predicted positive pixels that are actually positive.
# * **Specificity (True Negative Rate):** Measures the proportion of negative ground truth pixels correctly predicted as negative.
#
# Using these metrics provides a comprehensive assessment of the model’s performance, addressing the limitations of using accuracy alone on imbalanced datasets.

# %%
# 5. PrecisionMetric
class PrecisionMetric(tf.keras.metrics.Metric):
    def __init__(self, name='precision', **kwargs):
        super(PrecisionMetric, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(name='pp', initializer='zeros')
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_true_pred = tf.round(tf.clip_by_value(y_true * y_pred, 0, 1))
        y_pred_rounded = tf.round(tf.clip_by_value(y_pred, 0, 1))
        tp = tf.reduce_sum(y_true_pred)
        pp = tf.reduce_sum(y_pred_rounded)
        self.true_positives.assign_add(tp)
        self.predicted_positives.assign_add(pp)
    
    def result(self):
        return self.true_positives / (self.predicted_positives + tf.keras.backend.epsilon())
    
    def reset_states(self):
        self.true_positives.assign(0.0)
        self.predicted_positives.assign(0.0)

# 6. SensitivityMetric (Recall)
class SensitivityMetric(tf.keras.metrics.Metric):
    def __init__(self, name='sensitivity', **kwargs):
        super(SensitivityMetric, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.possible_positives = self.add_weight(name='pp', initializer='zeros')
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_true_pred = tf.round(tf.clip_by_value(y_true * y_pred, 0, 1))
        y_true_rounded = tf.round(tf.clip_by_value(y_true, 0, 1))
        tp = tf.reduce_sum(y_true_pred)
        pp = tf.reduce_sum(y_true_rounded)
        self.true_positives.assign_add(tp)
        self.possible_positives.assign_add(pp)
    
    def result(self):
        return self.true_positives / (self.possible_positives + tf.keras.backend.epsilon())
    
    def reset_states(self):
        self.true_positives.assign(0.0)
        self.possible_positives.assign(0.0)

# 7. SpecificityMetric
class SpecificityMetric(tf.keras.metrics.Metric):
    def __init__(self, name='specificity', **kwargs):
        super(SpecificityMetric, self).__init__(name=name, **kwargs)
        self.true_negatives = self.add_weight(name='tn', initializer='zeros')
        self.possible_negatives = self.add_weight(name='pn', initializer='zeros')
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        one_minus_y_true = 1 - y_true
        one_minus_y_pred = 1 - y_pred
        tn = tf.reduce_sum(tf.round(tf.clip_by_value(one_minus_y_true * one_minus_y_pred, 0, 1)))
        pn = tf.reduce_sum(tf.round(tf.clip_by_value(one_minus_y_true, 0, 1)))
        self.true_negatives.assign_add(tn)
        self.possible_negatives.assign_add(pn)
    
    def result(self):
        return self.true_negatives / (self.possible_negatives + tf.keras.backend.epsilon())
    
    def reset_states(self):
        self.true_negatives.assign(0.0)
        self.possible_negatives.assign(0.0)

# %% [markdown]
# ## **Define Segmentation Model**
#
# **U-Net**
#
# We will use the U-Net architecture, a convolutional neural network (CNN) specifically designed for biomedical image segmentation. U-Net is particularly effective for segmenting regions of interest that are small and have complex shapes, such as tumors in MRI scans. This architecture was introduced in 2015 by Olaf Ronneberger, Philipp Fischer, and Thomas Brox in their paper U-Net: Convolutional Networks for Biomedical Image Segmentation.
#
# Since the BraTS2020 dataset consists of 3D images, with each image comprising multiple 2D slices in three orthogonal planes, we have two options: using a 2D U-Net or a 3D U-Net.
#
# * **3D U-Net:** More suitable for leveraging the 3D spatial context of the images, reducing the risk of false positives and false negatives from partial information in individual slices. However, it requires more computational resources and memory.
# * **2D U-Net:** Faster and requires less memory, advantageous when working with large datasets or limited computational resources.
#
# In practice, it’s useful to try both architectures and compare their performance. We will opt for a 2D U-Net implementation due to its efficiency and lower resource requirements.

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# ![Unet.png](data:image/png;base64,...)

# %%
# Build and Plot the Model
with strategy.scope():
    input_layer = tf.keras.layers.Input((IMG_SIZE, IMG_SIZE, 4))
    model = build_unet(input_layer, 'he_normal', 0.2)
    model.compile(
        loss="categorical_crossentropy",
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        metrics=[
            'accuracy',
            tf.keras.metrics.MeanIoU(num_classes=4),
            DiceCoefMetric(),
            DiceCoefNecroticMetric(),
            DiceCoefEdemaMetric(),
            DiceCoefEnhancingMetric(),
            PrecisionMetric(),
            SensitivityMetric(),
            SpecificityMetric()
        ]
    )

# %%
plot_model(model,
           show_shapes = True,
           show_dtype=False,
           show_layer_names = True,
           rankdir = 'TB',
           expand_nested = False,
           dpi = 70)

# %%
# Set Up Callbacks
callbacks = [
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                            patience=2, min_lr=0.000001, verbose=1),
      keras.callbacks.ModelCheckpoint(filepath='model_.{epoch:02d}-{val_loss:.6f}.weights.h5',
                                verbose=1, save_best_only=True, save_weights_only=True),
      CSVLogger('training.log', separator=',', append=False)
    ]

# %% [markdown]
# ## **Train and Save the Model**
#
# We are now ready to train the deep neural network using the .fit() keras method. We will pass our callbacks to this method to be executed during the training process which will last for 35 epochs.

# %%
history = model.fit(
    training_generator,
    epochs=25,
    callbacks=callbacks,
    validation_data=valid_generator
)

model.save("/kaggle/working/UNet_idev1_MRI_All4.keras")
# Out:
# Epoch 1/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8986 - dice_coef: 0.2059 - dice_coef_edema: 0.0482 - dice_coef_enhancing: 0.0199 - dice_coef_necrotic: 0.0182 - loss: 0.8296 - mean_io_u: 0.4230 - precision: 0.9564 - sensitivity: 0.6538 - specificity: 0.9956
# Epoch 1: val_loss improved from inf to 0.08236, saving model to model_.01-0.082356.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 375s 5s/step - accuracy: 0.8996 - dice_coef: 0.2064 - dice_coef_edema: 0.0485 - dice_coef_enhancing: 0.0200 - dice_coef_necrotic: 0.0184 - loss: 0.8227 - mean_io_u: 0.4232 - precision: 0.9567 - sensitivity: 0.6570 - specificity: 0.9955 - val_accuracy: 0.9837 - val_dice_coef: 0.2598 - val_dice_coef_edema: 0.0402 - val_dice_coef_enhancing: 0.0117 - val_dice_coef_necrotic: 0.0134 - val_loss: 0.0824 - val_mean_io_u: 0.6508 - val_precision: 0.9837 - val_sensitivity: 0.9838 - val_specificity: 0.9946 - learning_rate: 0.0010
# Epoch 2/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9821 - dice_coef: 0.2758 - dice_coef_edema: 0.1339 - dice_coef_enhancing: 0.0575 - dice_coef_necrotic: 0.0854 - loss: 0.0777 - mean_io_u: 0.5239 - precision: 0.9822 - sensitivity: 0.9819 - specificity: 0.9941
# Epoch 2: val_loss improved from 0.08236 to 0.07111, saving model to model_.02-0.071111.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 286s 4s/step - accuracy: 0.9821 - dice_coef: 0.2759 - dice_coef_edema: 0.1341 - dice_coef_enhancing: 0.0577 - dice_coef_necrotic: 0.0858 - loss: 0.0777 - mean_io_u: 0.5240 - precision: 0.9822 - sensitivity: 0.9819 - specificity: 0.9941 - val_accuracy: 0.9821 - val_dice_coef: 0.2870 - val_dice_coef_edema: 0.1232 - val_dice_coef_enhancing: 0.0394 - val_dice_coef_necrotic: 0.1004 - val_loss: 0.0711 - val_mean_io_u: 0.6321 - val_precision: 0.9827 - val_sensitivity: 0.9820 - val_specificity: 0.9942 - learning_rate: 0.0010
# Epoch 3/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9828 - dice_coef: 0.2900 - dice_coef_edema: 0.1614 - dice_coef_enhancing: 0.0797 - dice_coef_necrotic: 0.1429 - loss: 0.0698 - mean_io_u: 0.5647 - precision: 0.9836 - sensitivity: 0.9821 - specificity: 0.9946
# Epoch 3: val_loss improved from 0.07111 to 0.06730, saving model to model_.03-0.067296.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 221s 3s/step - accuracy: 0.9828 - dice_coef: 0.2900 - dice_coef_edema: 0.1616 - dice_coef_enhancing: 0.0798 - dice_coef_necrotic: 0.1428 - loss: 0.0698 - mean_io_u: 0.5649 - precision: 0.9836 - sensitivity: 0.9821 - specificity: 0.9946 - val_accuracy: 0.9824 - val_dice_coef: 0.3032 - val_dice_coef_edema: 0.1975 - val_dice_coef_enhancing: 0.0764 - val_dice_coef_necrotic: 0.1434 - val_loss: 0.0673 - val_mean_io_u: 0.6850 - val_precision: 0.9848 - val_sensitivity: 0.9806 - val_specificity: 0.9949 - learning_rate: 0.0010
# Epoch 4/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9818 - dice_coef: 0.3063 - dice_coef_edema: 0.2151 - dice_coef_enhancing: 0.1146 - dice_coef_necrotic: 0.1799 - loss: 0.0669 - mean_io_u: 0.5485 - precision: 0.9844 - sensitivity: 0.9805 - specificity: 0.9948
# Epoch 4: val_loss improved from 0.06730 to 0.05169, saving model to model_.04-0.051689.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 225s 3s/step - accuracy: 0.9818 - dice_coef: 0.3065 - dice_coef_edema: 0.2152 - dice_coef_enhancing: 0.1148 - dice_coef_necrotic: 0.1803 - loss: 0.0668 - mean_io_u: 0.5483 - precision: 0.9845 - sensitivity: 0.9805 - specificity: 0.9948 - val_accuracy: 0.9839 - val_dice_coef: 0.3296 - val_dice_coef_edema: 0.2720 - val_dice_coef_enhancing: 0.1618 - val_dice_coef_necrotic: 0.2044 - val_loss: 0.0517 - val_mean_io_u: 0.6394 - val_precision: 0.9881 - val_sensitivity: 0.9825 - val_specificity: 0.9960 - learning_rate: 0.0010
# Epoch 5/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9847 - dice_coef: 0.3485 - dice_coef_edema: 0.2980 - dice_coef_enhancing: 0.1893 - dice_coef_necrotic: 0.2653 - loss: 0.0465 - mean_io_u: 0.5700 - precision: 0.9907 - sensitivity: 0.9817 - specificity: 0.9968
# Epoch 5: val_loss improved from 0.05169 to 0.05136, saving model to model_.05-0.051357.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 208s 3s/step - accuracy: 0.9847 - dice_coef: 0.3486 - dice_coef_edema: 0.2982 - dice_coef_enhancing: 0.1894 - dice_coef_necrotic: 0.2656 - loss: 0.0465 - mean_io_u: 0.5701 - precision: 0.9907 - sensitivity: 0.9817 - specificity: 0.9968 - val_accuracy: 0.9861 - val_dice_coef: 0.3328 - val_dice_coef_edema: 0.2559 - val_dice_coef_enhancing: 0.0817 - val_dice_coef_necrotic: 0.1576 - val_loss: 0.0514 - val_mean_io_u: 0.6176 - val_precision: 0.9882 - val_sensitivity: 0.9841 - val_specificity: 0.9960 - learning_rate: 0.0010
# Epoch 6/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9834 - dice_coef: 0.3572 - dice_coef_edema: 0.3339 - dice_coef_enhancing: 0.1934 - dice_coef_necrotic: 0.2867 - loss: 0.0519 - mean_io_u: 0.6189 - precision: 0.9901 - sensitivity: 0.9791 - specificity: 0.9966
# Epoch 6: val_loss improved from 0.05136 to 0.04959, saving model to model_.06-0.049585.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 219s 3s/step - accuracy: 0.9834 - dice_coef: 0.3571 - dice_coef_edema: 0.3335 - dice_coef_enhancing: 0.1935 - dice_coef_necrotic: 0.2865 - loss: 0.0520 - mean_io_u: 0.6186 - precision: 0.9901 - sensitivity: 0.9791 - specificity: 0.9966 - val_accuracy: 0.9848 - val_dice_coef: 0.3441 - val_dice_coef_edema: 0.3101 - val_dice_coef_enhancing: 0.1956 - val_dice_coef_necrotic: 0.2543 - val_loss: 0.0496 - val_mean_io_u: 0.5725 - val_precision: 0.9897 - val_sensitivity: 0.9824 - val_specificity: 0.9965 - learning_rate: 0.0010
# Epoch 7/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9831 - dice_coef: 0.3245 - dice_coef_edema: 0.2316 - dice_coef_enhancing: 0.1548 - dice_coef_necrotic: 0.2191 - loss: 0.0609 - mean_io_u: 0.5867 - precision: 0.9864 - sensitivity: 0.9816 - specificity: 0.9954
# Epoch 7: val_loss improved from 0.04959 to 0.04927, saving model to model_.07-0.049274.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 231s 3s/step - accuracy: 0.9831 - dice_coef: 0.3246 - dice_coef_edema: 0.2322 - dice_coef_enhancing: 0.1550 - dice_coef_necrotic: 0.2196 - loss: 0.0609 - mean_io_u: 0.5864 - precision: 0.9864 - sensitivity: 0.9816 - specificity: 0.9954 - val_accuracy: 0.9847 - val_dice_coef: 0.3597 - val_dice_coef_edema: 0.3390 - val_dice_coef_enhancing: 0.1632 - val_dice_coef_necrotic: 0.2965 - val_loss: 0.0493 - val_mean_io_u: 0.5788 - val_precision: 0.9891 - val_sensitivity: 0.9823 - val_specificity: 0.9963 - learning_rate: 0.0010
# Epoch 8/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9849 - dice_coef: 0.3588 - dice_coef_edema: 0.3329 - dice_coef_enhancing: 0.2059 - dice_coef_necrotic: 0.3000 - loss: 0.0481 - mean_io_u: 0.6029 - precision: 0.9910 - sensitivity: 0.9811 - specificity: 0.9969
# Epoch 8: val_loss improved from 0.04927 to 0.04246, saving model to model_.08-0.042460.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - accuracy: 0.9849 - dice_coef: 0.3589 - dice_coef_edema: 0.3331 - dice_coef_enhancing: 0.2059 - dice_coef_necrotic: 0.3001 - loss: 0.0481 - mean_io_u: 0.6034 - precision: 0.9910 - sensitivity: 0.9811 - specificity: 0.9969 - val_accuracy: 0.9866 - val_dice_coef: 0.3746 - val_dice_coef_edema: 0.4457 - val_dice_coef_enhancing: 0.2724 - val_dice_coef_necrotic: 0.3254 - val_loss: 0.0425 - val_mean_io_u: 0.5103 - val_precision: 0.9925 - val_sensitivity: 0.9818 - val_specificity: 0.9974 - learning_rate: 0.0010
# Epoch 9/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9847 - dice_coef: 0.3937 - dice_coef_edema: 0.4069 - dice_coef_enhancing: 0.2952 - dice_coef_necrotic: 0.3754 - loss: 0.0435 - mean_io_u: 0.5719 - precision: 0.9926 - sensitivity: 0.9794 - specificity: 0.9974
# Epoch 9: val_loss improved from 0.04246 to 0.03601, saving model to model_.09-0.036011.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 218s 3s/step - accuracy: 0.9847 - dice_coef: 0.3936 - dice_coef_edema: 0.4069 - dice_coef_enhancing: 0.2951 - dice_coef_necrotic: 0.3749 - loss: 0.0435 - mean_io_u: 0.5725 - precision: 0.9926 - sensitivity: 0.9794 - specificity: 0.9974 - val_accuracy: 0.9869 - val_dice_coef: 0.3826 - val_dice_coef_edema: 0.4489 - val_dice_coef_enhancing: 0.2675 - val_dice_coef_necrotic: 0.2738 - val_loss: 0.0360 - val_mean_io_u: 0.5905 - val_precision: 0.9929 - val_sensitivity: 0.9829 - val_specificity: 0.9975 - learning_rate: 0.0010
# Epoch 10/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9864 - dice_coef: 0.4018 - dice_coef_edema: 0.4410 - dice_coef_enhancing: 0.3236 - dice_coef_necrotic: 0.3241 - loss: 0.0378 - mean_io_u: 0.6104 - precision: 0.9933 - sensitivity: 0.9817 - specificity: 0.9976
# Epoch 10: val_loss did not improve from 0.03601
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 223s 3s/step - accuracy: 0.9864 - dice_coef: 0.4017 - dice_coef_edema: 0.4407 - dice_coef_enhancing: 0.3232 - dice_coef_necrotic: 0.3238 - loss: 0.0379 - mean_io_u: 0.6104 - precision: 0.9933 - sensitivity: 0.9817 - specificity: 0.9976 - val_accuracy: 0.9844 - val_dice_coef: 0.3563 - val_dice_coef_edema: 0.4145 - val_dice_coef_enhancing: 0.2734 - val_dice_coef_necrotic: 0.3087 - val_loss: 0.0541 - val_mean_io_u: 0.5142 - val_precision: 0.9934 - val_sensitivity: 0.9761 - val_specificity: 0.9976 - learning_rate: 0.0010
# Epoch 11/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9858 - dice_coef: 0.3797 - dice_coef_edema: 0.3726 - dice_coef_enhancing: 0.2558 - dice_coef_necrotic: 0.3467 - loss: 0.0447 - mean_io_u: 0.5540 - precision: 0.9924 - sensitivity: 0.9805 - specificity: 0.9973
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 11: val_loss did not improve from 0.03601
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 224s 3s/step - accuracy: 0.9858 - dice_coef: 0.3800 - dice_coef_edema: 0.3731 - dice_coef_enhancing: 0.2562 - dice_coef_necrotic: 0.3474 - loss: 0.0446 - mean_io_u: 0.5541 - precision: 0.9924 - sensitivity: 0.9805 - specificity: 0.9973 - val_accuracy: 0.9861 - val_dice_coef: 0.3902 - val_dice_coef_edema: 0.4342 - val_dice_coef_enhancing: 0.2392 - val_dice_coef_necrotic: 0.3041 - val_loss: 0.0427 - val_mean_io_u: 0.5692 - val_precision: 0.9909 - val_sensitivity: 0.9814 - val_specificity: 0.9969 - learning_rate: 0.0010
# Epoch 12/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9873 - dice_coef: 0.4247 - dice_coef_edema: 0.4891 - dice_coef_enhancing: 0.3428 - dice_coef_necrotic: 0.3890 - loss: 0.0338 - mean_io_u: 0.5926 - precision: 0.9944 - sensitivity: 0.9813 - specificity: 0.9979
# Epoch 12: val_loss improved from 0.03601 to 0.03317, saving model to model_.12-0.033170.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 221s 3s/step - accuracy: 0.9873 - dice_coef: 0.4247 - dice_coef_edema: 0.4891 - dice_coef_enhancing: 0.3429 - dice_coef_necrotic: 0.3892 - loss: 0.0338 - mean_io_u: 0.5928 - precision: 0.9944 - sensitivity: 0.9813 - specificity: 0.9979 - val_accuracy: 0.9887 - val_dice_coef: 0.4014 - val_dice_coef_edema: 0.4946 - val_dice_coef_enhancing: 0.3091 - val_dice_coef_necrotic: 0.2496 - val_loss: 0.0332 - val_mean_io_u: 0.5925 - val_precision: 0.9940 - val_sensitivity: 0.9833 - val_specificity: 0.9978 - learning_rate: 2.0000e-04
# Epoch 13/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9882 - dice_coef: 0.4374 - dice_coef_edema: 0.5046 - dice_coef_enhancing: 0.3728 - dice_coef_necrotic: 0.4087 - loss: 0.0314 - mean_io_u: 0.6224 - precision: 0.9945 - sensitivity: 0.9824 - specificity: 0.9980
# Epoch 13: val_loss improved from 0.03317 to 0.03031, saving model to model_.13-0.030311.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 232s 3s/step - accuracy: 0.9882 - dice_coef: 0.4374 - dice_coef_edema: 0.5046 - dice_coef_enhancing: 0.3728 - dice_coef_necrotic: 0.4089 - loss: 0.0314 - mean_io_u: 0.6225 - precision: 0.9945 - sensitivity: 0.9824 - specificity: 0.9980 - val_accuracy: 0.9907 - val_dice_coef: 0.4313 - val_dice_coef_edema: 0.5987 - val_dice_coef_enhancing: 0.3550 - val_dice_coef_necrotic: 0.3377 - val_loss: 0.0303 - val_mean_io_u: 0.6424 - val_precision: 0.9945 - val_sensitivity: 0.9853 - val_specificity: 0.9980 - learning_rate: 2.0000e-04
# Epoch 14/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9872 - dice_coef: 0.4349 - dice_coef_edema: 0.4929 - dice_coef_enhancing: 0.3613 - dice_coef_necrotic: 0.4078 - loss: 0.0348 - mean_io_u: 0.6466 - precision: 0.9936 - sensitivity: 0.9812 - specificity: 0.9977
# Epoch 14: val_loss did not improve from 0.03031
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 237s 3s/step - accuracy: 0.9872 - dice_coef: 0.4350 - dice_coef_edema: 0.4929 - dice_coef_enhancing: 0.3615 - dice_coef_necrotic: 0.4078 - loss: 0.0348 - mean_io_u: 0.6466 - precision: 0.9936 - sensitivity: 0.9812 - specificity: 0.9977 - val_accuracy: 0.9892 - val_dice_coef: 0.4388 - val_dice_coef_edema: 0.5737 - val_dice_coef_enhancing: 0.3995 - val_dice_coef_necrotic: 0.3768 - val_loss: 0.0324 - val_mean_io_u: 0.6386 - val_precision: 0.9946 - val_sensitivity: 0.9823 - val_specificity: 0.9980 - learning_rate: 2.0000e-04
# Epoch 15/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9889 - dice_coef: 0.4442 - dice_coef_edema: 0.5355 - dice_coef_enhancing: 0.3958 - dice_coef_necrotic: 0.3907 - loss: 0.0300 - mean_io_u: 0.6791 - precision: 0.9944 - sensitivity: 0.9835 - specificity: 0.9980
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 15: val_loss did not improve from 0.03031
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 237s 3s/step - accuracy: 0.9889 - dice_coef: 0.4443 - dice_coef_edema: 0.5353 - dice_coef_enhancing: 0.3959 - dice_coef_necrotic: 0.3911 - loss: 0.0300 - mean_io_u: 0.6790 - precision: 0.9944 - sensitivity: 0.9834 - specificity: 0.9980 - val_accuracy: 0.9884 - val_dice_coef: 0.4380 - val_dice_coef_edema: 0.5240 - val_dice_coef_enhancing: 0.3664 - val_dice_coef_necrotic: 0.3537 - val_loss: 0.0367 - val_mean_io_u: 0.6628 - val_precision: 0.9928 - val_sensitivity: 0.9828 - val_specificity: 0.9974 - learning_rate: 2.0000e-04
# Epoch 16/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9881 - dice_coef: 0.4539 - dice_coef_edema: 0.5353 - dice_coef_enhancing: 0.3896 - dice_coef_necrotic: 0.4323 - loss: 0.0321 - mean_io_u: 0.6705 - precision: 0.9938 - sensitivity: 0.9824 - specificity: 0.9978
# Epoch 16: val_loss did not improve from 0.03031
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 229s 3s/step - accuracy: 0.9881 - dice_coef: 0.4539 - dice_coef_edema: 0.5352 - dice_coef_enhancing: 0.3897 - dice_coef_necrotic: 0.4322 - loss: 0.0322 - mean_io_u: 0.6704 - precision: 0.9938 - sensitivity: 0.9824 - specificity: 0.9978 - val_accuracy: 0.9891 - val_dice_coef: 0.4482 - val_dice_coef_edema: 0.5504 - val_dice_coef_enhancing: 0.4140 - val_dice_coef_necrotic: 0.3639 - val_loss: 0.0370 - val_mean_io_u: 0.6688 - val_precision: 0.9934 - val_sensitivity: 0.9841 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 17/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9884 - dice_coef: 0.4581 - dice_coef_edema: 0.5397 - dice_coef_enhancing: 0.4204 - dice_coef_necrotic: 0.4366 - loss: 0.0306 - mean_io_u: 0.6707 - precision: 0.9942 - sensitivity: 0.9829 - specificity: 0.9979
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 17: val_loss did not improve from 0.03031
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 241s 3s/step - accuracy: 0.9884 - dice_coef: 0.4581 - dice_coef_edema: 0.5397 - dice_coef_enhancing: 0.4202 - dice_coef_necrotic: 0.4363 - loss: 0.0306 - mean_io_u: 0.6708 - precision: 0.9942 - sensitivity: 0.9829 - specificity: 0.9979 - val_accuracy: 0.9888 - val_dice_coef: 0.4394 - val_dice_coef_edema: 0.5593 - val_dice_coef_enhancing: 0.3979 - val_dice_coef_necrotic: 0.3167 - val_loss: 0.0329 - val_mean_io_u: 0.6623 - val_precision: 0.9937 - val_sensitivity: 0.9837 - val_specificity: 0.9978 - learning_rate: 4.0000e-05
# Epoch 18/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9882 - dice_coef: 0.4536 - dice_coef_edema: 0.5511 - dice_coef_enhancing: 0.3968 - dice_coef_necrotic: 0.4113 - loss: 0.0327 - mean_io_u: 0.6620 - precision: 0.9941 - sensitivity: 0.9823 - specificity: 0.9978
# Epoch 18: val_loss did not improve from 0.03031
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 242s 3s/step - accuracy: 0.9882 - dice_coef: 0.4535 - dice_coef_edema: 0.5510 - dice_coef_enhancing: 0.3966 - dice_coef_necrotic: 0.4110 - loss: 0.0327 - mean_io_u: 0.6619 - precision: 0.9941 - sensitivity: 0.9823 - specificity: 0.9978 - val_accuracy: 0.9891 - val_dice_coef: 0.4421 - val_dice_coef_edema: 0.5787 - val_dice_coef_enhancing: 0.3710 - val_dice_coef_necrotic: 0.3674 - val_loss: 0.0304 - val_mean_io_u: 0.6765 - val_precision: 0.9939 - val_sensitivity: 0.9836 - val_specificity: 0.9978 - learning_rate: 8.0000e-06
# Epoch 19/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9889 - dice_coef: 0.4514 - dice_coef_edema: 0.5474 - dice_coef_enhancing: 0.3986 - dice_coef_necrotic: 0.4091 - loss: 0.0302 - mean_io_u: 0.6633 - precision: 0.9945 - sensitivity: 0.9830 - specificity: 0.9980
# Epoch 19: val_loss improved from 0.03031 to 0.02790, saving model to model_.19-0.027898.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 238s 3s/step - accuracy: 0.9889 - dice_coef: 0.4515 - dice_coef_edema: 0.5475 - dice_coef_enhancing: 0.3984 - dice_coef_necrotic: 0.4093 - loss: 0.0302 - mean_io_u: 0.6633 - precision: 0.9945 - sensitivity: 0.9829 - specificity: 0.9980 - val_accuracy: 0.9899 - val_dice_coef: 0.4560 - val_dice_coef_edema: 0.5852 - val_dice_coef_enhancing: 0.4283 - val_dice_coef_necrotic: 0.3791 - val_loss: 0.0279 - val_mean_io_u: 0.6710 - val_precision: 0.9942 - val_sensitivity: 0.9850 - val_specificity: 0.9979 - learning_rate: 8.0000e-06
# Epoch 20/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9885 - dice_coef: 0.4548 - dice_coef_edema: 0.5507 - dice_coef_enhancing: 0.4075 - dice_coef_necrotic: 0.4003 - loss: 0.0303 - mean_io_u: 0.6742 - precision: 0.9942 - sensitivity: 0.9831 - specificity: 0.9979
# Epoch 20: val_loss did not improve from 0.02790
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 242s 3s/step - accuracy: 0.9885 - dice_coef: 0.4548 - dice_coef_edema: 0.5509 - dice_coef_enhancing: 0.4075 - dice_coef_necrotic: 0.4005 - loss: 0.0303 - mean_io_u: 0.6742 - precision: 0.9942 - sensitivity: 0.9831 - specificity: 0.9979 - val_accuracy: 0.9883 - val_dice_coef: 0.4476 - val_dice_coef_edema: 0.5670 - val_dice_coef_enhancing: 0.3657 - val_dice_coef_necrotic: 0.3839 - val_loss: 0.0320 - val_mean_io_u: 0.6618 - val_precision: 0.9930 - val_sensitivity: 0.9834 - val_specificity: 0.9975 - learning_rate: 8.0000e-06
# Epoch 21/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9888 - dice_coef: 0.4552 - dice_coef_edema: 0.5624 - dice_coef_enhancing: 0.4016 - dice_coef_necrotic: 0.4080 - loss: 0.0308 - mean_io_u: 0.6650 - precision: 0.9944 - sensitivity: 0.9829 - specificity: 0.9980
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 21: val_loss did not improve from 0.02790
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 245s 3s/step - accuracy: 0.9887 - dice_coef: 0.4553 - dice_coef_edema: 0.5625 - dice_coef_enhancing: 0.4017 - dice_coef_necrotic: 0.4080 - loss: 0.0309 - mean_io_u: 0.6651 - precision: 0.9944 - sensitivity: 0.9829 - specificity: 0.9980 - val_accuracy: 0.9877 - val_dice_coef: 0.4515 - val_dice_coef_edema: 0.5954 - val_dice_coef_enhancing: 0.3573 - val_dice_coef_necrotic: 0.3568 - val_loss: 0.0372 - val_mean_io_u: 0.6852 - val_precision: 0.9923 - val_sensitivity: 0.9834 - val_specificity: 0.9973 - learning_rate: 8.0000e-06
# Epoch 22/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9886 - dice_coef: 0.4531 - dice_coef_edema: 0.5425 - dice_coef_enhancing: 0.3773 - dice_coef_necrotic: 0.4237 - loss: 0.0307 - mean_io_u: 0.6714 - precision: 0.9942 - sensitivity: 0.9829 - specificity: 0.9979
# Epoch 22: val_loss did not improve from 0.02790
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 241s 3s/step - accuracy: 0.9886 - dice_coef: 0.4530 - dice_coef_edema: 0.5426 - dice_coef_enhancing: 0.3774 - dice_coef_necrotic: 0.4235 - loss: 0.0307 - mean_io_u: 0.6713 - precision: 0.9942 - sensitivity: 0.9829 - specificity: 0.9979 - val_accuracy: 0.9869 - val_dice_coef: 0.4435 - val_dice_coef_edema: 0.5598 - val_dice_coef_enhancing: 0.3464 - val_dice_coef_necrotic: 0.3661 - val_loss: 0.0353 - val_mean_io_u: 0.6689 - val_precision: 0.9928 - val_sensitivity: 0.9816 - val_specificity: 0.9975 - learning_rate: 1.6000e-06
# Epoch 23/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9885 - dice_coef: 0.4554 - dice_coef_edema: 0.5479 - dice_coef_enhancing: 0.3922 - dice_coef_necrotic: 0.4210 - loss: 0.0300 - mean_io_u: 0.6670 - precision: 0.9942 - sensitivity: 0.9832 - specificity: 0.9979
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 23: val_loss did not improve from 0.02790
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 240s 3s/step - accuracy: 0.9885 - dice_coef: 0.4554 - dice_coef_edema: 0.5479 - dice_coef_enhancing: 0.3921 - dice_coef_necrotic: 0.4209 - loss: 0.0300 - mean_io_u: 0.6670 - precision: 0.9942 - sensitivity: 0.9832 - specificity: 0.9979 - val_accuracy: 0.9893 - val_dice_coef: 0.4366 - val_dice_coef_edema: 0.5525 - val_dice_coef_enhancing: 0.3518 - val_dice_coef_necrotic: 0.3356 - val_loss: 0.0324 - val_mean_io_u: 0.6425 - val_precision: 0.9939 - val_sensitivity: 0.9852 - val_specificity: 0.9979 - learning_rate: 1.6000e-06
# Epoch 24/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9885 - dice_coef: 0.4592 - dice_coef_edema: 0.5425 - dice_coef_enhancing: 0.3954 - dice_coef_necrotic: 0.4338 - loss: 0.0308 - mean_io_u: 0.6729 - precision: 0.9941 - sensitivity: 0.9831 - specificity: 0.9979
# Epoch 24: val_loss did not improve from 0.02790
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 242s 3s/step - accuracy: 0.9884 - dice_coef: 0.4591 - dice_coef_edema: 0.5429 - dice_coef_enhancing: 0.3953 - dice_coef_necrotic: 0.4332 - loss: 0.0308 - mean_io_u: 0.6728 - precision: 0.9941 - sensitivity: 0.9831 - specificity: 0.9979 - val_accuracy: 0.9884 - val_dice_coef: 0.4413 - val_dice_coef_edema: 0.5523 - val_dice_coef_enhancing: 0.4234 - val_dice_coef_necrotic: 0.2926 - val_loss: 0.0372 - val_mean_io_u: 0.6626 - val_precision: 0.9929 - val_sensitivity: 0.9832 - val_specificity: 0.9975 - learning_rate: 1.0000e-06
# Epoch 25/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9892 - dice_coef: 0.4600 - dice_coef_edema: 0.5684 - dice_coef_enhancing: 0.3942 - dice_coef_necrotic: 0.4301 - loss: 0.0287 - mean_io_u: 0.6744 - precision: 0.9944 - sensitivity: 0.9841 - specificity: 0.9980
# Epoch 25: val_loss did not improve from 0.02790
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 244s 4s/step - accuracy: 0.9892 - dice_coef: 0.4599 - dice_coef_edema: 0.5681 - dice_coef_enhancing: 0.3943 - dice_coef_necrotic: 0.4299 - loss: 0.0287 - mean_io_u: 0.6743 - precision: 0.9944 - sensitivity: 0.9841 - specificity: 0.9980 - val_accuracy: 0.9891 - val_dice_coef: 0.4505 - val_dice_coef_edema: 0.5834 - val_dice_coef_enhancing: 0.3702 - val_dice_coef_necrotic: 0.3680 - val_loss: 0.0316 - val_mean_io_u: 0.6640 - val_precision: 0.9936 - val_sensitivity: 0.9827 - val_specificity: 0.9977 - learning_rate: 1.0000e-06

# %%
model.save("/kaggle/working/UNet_idev1_MRI_All4.keras")

# %% [markdown]
# ## **Load Trained Model**
# We will load our trained neural network model using Keras. The ``load_model`` method allows us to reload the saved model, including custom metrics and loss functions we defined during training.
#
# We specify the path to our saved model and provide a dictionary of custom_objects to ensure that our custom metrics and loss functions are correctly recognized by Keras. Setting compile=False allows us to load the model architecture and weights without compiling it immediately, giving us the flexibility to adjust compilation settings if needed.

# %%
model = keras.models.load_model(
    '/kaggle/working/UNet_idev1_MRI_All4.keras',
    custom_objects={
        "accuracy": tf.keras.metrics.MeanIoU(num_classes=4),
        "dice_coef": DiceCoefMetric,
        "dice_coef_necrotic": DiceCoefNecroticMetric,
        "dice_coef_edema": DiceCoefEdemaMetric,
        "dice_coef_enhancing": DiceCoefEnhancingMetric,
        "precision": PrecisionMetric,
        "sensitivity": SensitivityMetric,
        "specificity": SpecificityMetric
    },
    compile=False
)

# %% [markdown]
# ## **Metrics Analysis**
# Now that the training is complete, we can examine the CSVLogger callback to gain insights into the training process and our model's performance. The CSVLogger records metrics such as accuracy, loss, Dice coefficient, and Mean IoU for each epoch, allowing us to track the model’s progress over time. By analyzing this log, we can identify trends, assess the effectiveness of our training strategy, and make informed decisions for future improvements. This thorough review ensures our model is performing optimally and ready for deployment.

# %%
column_names = ["epoch","accuracy","dice_coef","dice_coef_edema","dice_coef_enhancing","dice_coef_necrotic",
                "learning_rate","loss","mean_io_u","precision","sensitivity","specificity","val_accuracy",
                "val_dice_coef","val_dice_coef_edema","val_dice_coef_enhancing","val_dice_coef_necrotic",
                "val_loss","val_mean_io_u","val_precision","val_sensitivity","val_specificity"]  # Modify based on actual data
history = pd.read_csv('/kaggle/working/training.log', sep=',', engine='c', names=column_names)

# %%
print(history.columns)
# Out:
# Index(['epoch', 'accuracy', 'dice_coef', 'dice_coef_edema',
#        'dice_coef_enhancing', 'dice_coef_necrotic', 'learning_rate', 'loss',
#        'mean_io_u', 'precision', 'sensitivity', 'specificity', 'val_accuracy',
#        'val_dice_coef', 'val_dice_coef_edema', 'val_dice_coef_enhancing',
#        'val_dice_coef_necrotic', 'val_loss', 'val_mean_io_u', 'val_precision',
#        'val_sensitivity', 'val_specificity'],
#       dtype='object')

# %%
history = pd.read_csv('/kaggle/working/training.log', sep=',')

hist=history

acc=hist["accuracy"]
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Validation mean IOU')
ax[3].legend()

plt.savefig('training_plots.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import tensorflow

# Compile a model and load our saved weights
IMG_SIZE = 128
input_layer = Input((IMG_SIZE, IMG_SIZE, 4))

best_saved_model = build_unet(input_layer, 'he_normal', 0.2)

best_saved_model.compile(
    loss="categorical_crossentropy",
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        DiceCoefMetric(),
        PrecisionMetric(),
        SensitivityMetric(),
        SpecificityMetric(),
        DiceCoefNecroticMetric(),
        DiceCoefEdemaMetric(),
        DiceCoefEnhancingMetric()
    ]
)

best_saved_model.load_weights('/kaggle/working/model_.19-0.027898.weights.h5')

# %%
def imageLoader(path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
    return np.array(image)

# %%
def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] )
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])
    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')
def predictByPath(case_path, case):
    # Create input array for 4 modalities
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 4))
    
    # Load each modality
    t1_path    = os.path.join(case_path, f'BraTS20_Training_{case}_t1.nii')
    t1ce_path  = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii')
    t2_path    = os.path.join(case_path, f'BraTS20_Training_{case}_t2.nii')
    flair_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii')
    
    t1    = nib.load(t1_path).get_fdata()
    t1ce  = nib.load(t1ce_path).get_fdata()
    t2    = nib.load(t2_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()
    
    for j in range(VOLUME_SLICES):
        slice_index = j + VOLUME_START_AT
        X[j, :, :, 0] = cv2.resize(t1[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 1] = cv2.resize(t1ce[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 2] = cv2.resize(t2[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 3] = cv2.resize(flair[:, :, slice_index], (IMG_SIZE, IMG_SIZE))
        
    # Normalize the input before prediction
    X_norm = X / np.max(X)
    return model.predict(X_norm, verbose=1)
def showPredictsById(case, start_slice=60):
    path = f"/kaggle/input/mlma-project/BraTS2020_TrainingData/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    
    # Load ground truth segmentation
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    
    # Load all four modalities
    t1    = nib.load(os.path.join(path, f'BraTS20_Training_{case}_t1.nii')).get_fdata()
    t1ce  = nib.load(os.path.join(path, f'BraTS20_Training_{case}_t1ce.nii')).get_fdata()
    t2    = nib.load(os.path.join(path, f'BraTS20_Training_{case}_t2.nii')).get_fdata()
    flair = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    
    # Get predicted segmentation from your predictByPath function
    p = predictByPath(path, case)
    
    # Extract predicted segmentation channels
    core = p[:,:,:,1]
    edema = p[:,:,:,2]
    enhancing = p[:,:,:,3]
    
    # Determine slice indices
    slice_idx = start_slice + VOLUME_START_AT  # for the original modalities and GT
    # For predictions, we assume p has VOLUME_SLICES slices; here we use start_slice index.
    
    # Create a figure with 2 rows and 5 columns
    fig, axs = plt.subplots(2, 5, figsize=(25, 10))
    
    # Row 0: Original modalities
    axs[0, 0].imshow(cv2.resize(t1[:, :, slice_idx], (IMG_SIZE, IMG_SIZE)), cmap='gray', interpolation='none')
    axs[0, 0].set_title('Original T1')
    
    axs[0, 1].imshow(cv2.resize(t1ce[:, :, slice_idx], (IMG_SIZE, IMG_SIZE)), cmap='gray', interpolation='none')
    axs[0, 1].set_title('Original T1ce')
    
    axs[0, 2].imshow(cv2.resize(t2[:, :, slice_idx], (IMG_SIZE, IMG_SIZE)), cmap='gray', interpolation='none')
    axs[0, 2].set_title('Original T2')
    
    axs[0, 3].imshow(cv2.resize(flair[:, :, slice_idx], (IMG_SIZE, IMG_SIZE)), cmap='gray', interpolation='none')
    axs[0, 3].set_title('Original FLAIR')
    
    # Leave the 5th subplot empty or use it for a montage if desired.
    axs[0, 4].axis('off')
    
    # Row 1: Ground truth and predictions
    curr_gt = cv2.resize(gt[:, :, slice_idx], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)
    axs[1, 0].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.5)
    axs[1, 0].set_title('Ground Truth')
    
    # For aggregated predicted segmentation, you can show the argmax across channels.
    pred_seg = np.argmax(p, axis=-1)
    pred_seg_slice = cv2.resize(pred_seg[start_slice, :, :], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)
    axs[1, 1].imshow(pred_seg_slice, cmap="jet", interpolation='none', alpha=0.5)
    axs[1, 1].set_title('Predicted Segmentation')
    
    axs[1, 2].imshow(cv2.resize(edema[start_slice, :, :], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST), cmap="OrRd", alpha=0.5)
    axs[1, 2].set_title(f'{SEGMENT_CLASSES[1]} predicted')
    
    axs[1, 3].imshow(cv2.resize(core[start_slice, :, :], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST), cmap="OrRd", alpha=0.5)
    axs[1, 3].set_title(f'{SEGMENT_CLASSES[2]} predicted')
    
    axs[1, 4].imshow(cv2.resize(enhancing[start_slice, :, :], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST), cmap="OrRd", alpha=0.5)
    axs[1, 4].set_title(f'{SEGMENT_CLASSES[3]} predicted')
    
    plt.tight_layout()
    plt.savefig('all_modalities_slice_sample.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
showPredictsById(case=test_ids[10][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '_t1ce.nii'
    flair_path = sample_path + '_flair.nii'
    t1_path = sample_path + '_t1.nii'
    t2_path = sample_path + '_t2.nii'

    # Extract the data from these paths
    t1    = nib.load(t1_path).get_fdata()
    t1ce  = nib.load(t1ce_path).get_fdata()
    t2    = nib.load(t2_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    # Create an empty array
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 4))

    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES):
        X[j,:,:,3] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,0] = cv2.resize(t1[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,2] = cv2.resize(t2[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    # Send our images to the CNN model and return predicted segmentation
    return model.predict(X/np.max(X), verbose=1)
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)

    # Get path of this patient
    random_sample_path = os.path.join(Train_Path, random_sample, random_sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)

    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')

    # Layers 1, 2, 3
    axstest[1].imshow(all, cmap, norm)
    axstest[1].set_title('Predicted Segmentation - all classes')

    # Layer 0
    axstest[2].imshow(zero)
    axstest[2].set_title('Predicted Segmentation - Not Tumor')

    # Layer 1
    axstest[3].imshow(first)
    axstest[3].set_title('Predicted Segmentation - Necrotic/Core')

    # Layer 2
    axstest[4].imshow(second)
    axstest[4].set_title('Predicted Segmentation - Edema')

    # Layer 3
    axstest[5].imshow(third)
    axstest[5].set_title('Predicted Segmentation - Enhancing')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.savefig('segmentation_slice_sample.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
show_predicted_segmentations(test_ids, 45, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Patient number:  BraTS20_Training_304

# %%
case = test_ids[15][-3:]
path = f"/kaggle/input/mlma-project/BraTS2020_TrainingData/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)

core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]

i=40 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'

gt[gt != eval_class] = 1 # use only one class for per class evaluation

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2)
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.savefig('prediction_sample.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
# Evaluate the model on the test data
model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        DiceCoefMetric(),
        PrecisionMetric(),
        SensitivityMetric(),
        SpecificityMetric(),
        DiceCoefNecroticMetric(),
        DiceCoefEdemaMetric(),
        DiceCoefEnhancingMetric()
    ]
)

# Evaluate the model on the test data
results = model.evaluate(test_generator, batch_size=100, callbacks=callbacks)

descriptions = [
    "Loss", "Accuracy", "MeanIOU", "Dice coefficient", 
    "Precision", "Sensitivity", "Specificity", 
    "Dice coef Necrotic", "Dice coef Edema", "Dice coef Enhancing"
]

# Combine results list and descriptions list and display each metric with its description
print("\nModel evaluation on the test set:")
print("==================================")
for metric, description in zip(results, descriptions):
    print(f"{description} : {round(metric, 4)}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.9911 - dice_coef: 0.4594 - dice_coef_edema: 0.5587 - dice_coef_enhancing: 0.4276 - dice_coef_necrotic: 0.4391 - loss: 0.0245 - mean_io_u_4: 0.5273 - precision: 0.9957 - sensitivity: 0.9869 - specificity: 0.9984
#
# Model evaluation on the test set:
# ==================================
# Loss : 0.0258
# Accuracy : 0.9908
# MeanIOU : 0.5
# Dice coefficient : 0.468
# Precision : 0.9952
# Sensitivity : 0.986
# Specificity : 0.9982
# Dice coef Necrotic : 0.4338
# Dice coef Edema : 0.5886
# Dice coef Enhancing : 0.4447

# %%
# Print the full lists of subject IDs for each dataset
print("Train subject IDs:", train_ids)
print("Validation subject IDs:", val_ids)
print("Test subject IDs:", test_ids)

# Now, get the batch IDs for each generator by using their internal indexes.
# (Since 'on_epoch_end()' already sets 'indexes', we can use that.)

# For the training generator:
print("\nBatch IDs in Training Generator:")
for i in range(len(training_generator)):
    # Calculate indices for the i-th batch
    batch_indices = training_generator.indexes[i * training_generator.batch_size:(i+1) * training_generator.batch_size]
    # Get corresponding subject IDs
    batch_ids = [training_generator.list_IDs[idx] for idx in batch_indices]
    print(f"Batch {i}:", batch_ids)

# For the validation generator:
print("\nBatch IDs in Validation Generator:")
for i in range(len(valid_generator)):
    batch_indices = valid_generator.indexes[i * valid_generator.batch_size:(i+1) * valid_generator.batch_size]
    batch_ids = [valid_generator.list_IDs[idx] for idx in batch_indices]
    print(f"Batch {i}:", batch_ids)

# For the test generator:
print("\nBatch IDs in Test Generator:")
for i in range(len(test_generator)):
    batch_indices = test_generator.indexes[i * test_generator.batch_size:(i+1) * test_generator.batch_size]
    batch_ids = [test_generator.list_IDs[idx] for idx in batch_indices]
    print(f"Batch {i}:", batch_ids)
# Out:
# Train subject IDs: ['BraTS20_Training_353', 'BraTS20_Training_250', 'BraTS20_Training_108', 'BraTS20_Training_050', 'BraTS20_Training_141', 'BraTS20_Training_220', 'BraTS20_Training_162', 'BraTS20_Training_344', 'BraTS20_Training_251', 'BraTS20_Training_360', 'BraTS20_Training_090', 'BraTS20_Training_144', 'BraTS20_Training_070', 'BraTS20_Training_322', 'BraTS20_Training_150', 'BraTS20_Training_234', 'BraTS20_Training_172', 'BraTS20_Training_111', 'BraTS20_Training_040', 'BraTS20_Training_135', 'BraTS20_Training_086', 'BraTS20_Training_368', 'BraTS20_Training_016', 'BraTS20_Training_147', 'BraTS20_Training_157', 'BraTS20_Training_186', 'BraTS20_Training_349', 'BraTS20_Training_100', 'BraTS20_Training_192', 'BraTS20_Training_210', 'BraTS20_Training_158', 'BraTS20_Training_067', 'BraTS20_Training_088', 'BraTS20_Training_184', 'BraTS20_Training_221', 'BraTS20_Training_112', 'BraTS20_Training_151', 'BraTS20_Training_275', 'BraTS20_Training_286', 'BraTS20_Training_030', 'BraTS20_Training_292', 'BraTS20_Training_313', 'BraTS20_Training_189', 'BraTS20_Training_005', 'BraTS20_Training_261', 'BraTS20_Training_314', 'BraTS20_Training_019', 'BraTS20_Training_180', 'BraTS20_Training_045', 'BraTS20_Training_303', 'BraTS20_Training_029', 'BraTS20_Training_053', 'BraTS20_Training_273', 'BraTS20_Training_081', 'BraTS20_Training_283', 'BraTS20_Training_264', 'BraTS20_Training_321', 'BraTS20_Training_330', 'BraTS20_Training_156', 'BraTS20_Training_233', 'BraTS20_Training_052', 'BraTS20_Training_164', 'BraTS20_Training_092', 'BraTS20_Training_007', 'BraTS20_Training_064', 'BraTS20_Training_171', 'BraTS20_Training_246', 'BraTS20_Training_193', 'BraTS20_Training_301', 'BraTS20_Training_201', 'BraTS20_Training_105', 'BraTS20_Training_215', 'BraTS20_Training_107', 'BraTS20_Training_305', 'BraTS20_Training_075', 'BraTS20_Training_020', 'BraTS20_Training_115', 'BraTS20_Training_079', 'BraTS20_Training_032', 'BraTS20_Training_068', 'BraTS20_Training_230', 'BraTS20_Training_139', 'BraTS20_Training_072', 'BraTS20_Training_098', 'BraTS20_Training_340', 'BraTS20_Training_204', 'BraTS20_Training_148', 'BraTS20_Training_300', 'BraTS20_Training_208', 'BraTS20_Training_102', 'BraTS20_Training_282', 'BraTS20_Training_126', 'BraTS20_Training_161', 'BraTS20_Training_265', 'BraTS20_Training_341', 'BraTS20_Training_037', 'BraTS20_Training_351', 'BraTS20_Training_354', 'BraTS20_Training_170', 'BraTS20_Training_362', 'BraTS20_Training_242', 'BraTS20_Training_051', 'BraTS20_Training_122', 'BraTS20_Training_027', 'BraTS20_Training_296', 'BraTS20_Training_179', 'BraTS20_Training_361', 'BraTS20_Training_270', 'BraTS20_Training_359', 'BraTS20_Training_229', 'BraTS20_Training_082', 'BraTS20_Training_138', 'BraTS20_Training_022', 'BraTS20_Training_077', 'BraTS20_Training_363', 'BraTS20_Training_120', 'BraTS20_Training_127', 'BraTS20_Training_183', 'BraTS20_Training_324', 'BraTS20_Training_089', 'BraTS20_Training_173', 'BraTS20_Training_133', 'BraTS20_Training_245', 'BraTS20_Training_060', 'BraTS20_Training_142', 'BraTS20_Training_155', 'BraTS20_Training_312', 'BraTS20_Training_191', 'BraTS20_Training_071', 'BraTS20_Training_239', 'BraTS20_Training_014', 'BraTS20_Training_248', 'BraTS20_Training_011', 'BraTS20_Training_335', 'BraTS20_Training_114', 'BraTS20_Training_366', 'BraTS20_Training_298', 'BraTS20_Training_080', 'BraTS20_Training_187', 'BraTS20_Training_326', 'BraTS20_Training_346', 'BraTS20_Training_272', 'BraTS20_Training_166', 'BraTS20_Training_124', 'BraTS20_Training_069', 'BraTS20_Training_062', 'BraTS20_Training_084', 'BraTS20_Training_134', 'BraTS20_Training_284', 'BraTS20_Training_211', 'BraTS20_Training_290', 'BraTS20_Training_196', 'BraTS20_Training_319', 'BraTS20_Training_087', 'BraTS20_Training_035', 'BraTS20_Training_182', 'BraTS20_Training_121', 'BraTS20_Training_228', 'BraTS20_Training_364', 'BraTS20_Training_257', 'BraTS20_Training_238', 'BraTS20_Training_367', 'BraTS20_Training_143', 'BraTS20_Training_369', 'BraTS20_Training_243', 'BraTS20_Training_16 ...
# Validation subject IDs: ['BraTS20_Training_085', 'BraTS20_Training_236', 'BraTS20_Training_350', 'BraTS20_Training_316', 'BraTS20_Training_318', 'BraTS20_Training_002', 'BraTS20_Training_028', 'BraTS20_Training_101', 'BraTS20_Training_055', 'BraTS20_Training_009', 'BraTS20_Training_110', 'BraTS20_Training_017', 'BraTS20_Training_038', 'BraTS20_Training_119', 'BraTS20_Training_066', 'BraTS20_Training_356', 'BraTS20_Training_025', 'BraTS20_Training_117', 'BraTS20_Training_357', 'BraTS20_Training_278', 'BraTS20_Training_181', 'BraTS20_Training_123', 'BraTS20_Training_049', 'BraTS20_Training_285', 'BraTS20_Training_169', 'BraTS20_Training_200', 'BraTS20_Training_198', 'BraTS20_Training_223', 'BraTS20_Training_339', 'BraTS20_Training_345', 'BraTS20_Training_244', 'BraTS20_Training_274', 'BraTS20_Training_059', 'BraTS20_Training_289', 'BraTS20_Training_178', 'BraTS20_Training_320', 'BraTS20_Training_146', 'BraTS20_Training_103', 'BraTS20_Training_259', 'BraTS20_Training_205', 'BraTS20_Training_336', 'BraTS20_Training_199', 'BraTS20_Training_334', 'BraTS20_Training_006', 'BraTS20_Training_190', 'BraTS20_Training_073', 'BraTS20_Training_137', 'BraTS20_Training_026', 'BraTS20_Training_041', 'BraTS20_Training_033', 'BraTS20_Training_343', 'BraTS20_Training_056', 'BraTS20_Training_001', 'BraTS20_Training_271', 'BraTS20_Training_177']
# Test subject IDs: ['BraTS20_Training_260', 'BraTS20_Training_347', 'BraTS20_Training_004', 'BraTS20_Training_116', 'BraTS20_Training_023', 'BraTS20_Training_094', 'BraTS20_Training_054', 'BraTS20_Training_202', 'BraTS20_Training_213', 'BraTS20_Training_031', 'BraTS20_Training_225', 'BraTS20_Training_268', 'BraTS20_Training_231', 'BraTS20_Training_021', 'BraTS20_Training_131', 'BraTS20_Training_209', 'BraTS20_Training_299', 'BraTS20_Training_291', 'BraTS20_Training_308', 'BraTS20_Training_307', 'BraTS20_Training_136', 'BraTS20_Training_227', 'BraTS20_Training_034', 'BraTS20_Training_043', 'BraTS20_Training_222', 'BraTS20_Training_206', 'BraTS20_Training_266', 'BraTS20_Training_010', 'BraTS20_Training_232', 'BraTS20_Training_185', 'BraTS20_Training_044', 'BraTS20_Training_255', 'BraTS20_Training_212', 'BraTS20_Training_118', 'BraTS20_Training_277', 'BraTS20_Training_095', 'BraTS20_Training_295', 'BraTS20_Training_132', 'BraTS20_Training_012', 'BraTS20_Training_304', 'BraTS20_Training_076', 'BraTS20_Training_096', 'BraTS20_Training_216', 'BraTS20_Training_083', 'BraTS20_Training_015', 'BraTS20_Training_047', 'BraTS20_Training_325', 'BraTS20_Training_106', 'BraTS20_Training_003', 'BraTS20_Training_267', 'BraTS20_Training_130', 'BraTS20_Training_241', 'BraTS20_Training_153', 'BraTS20_Training_311', 'BraTS20_Training_288', 'BraTS20_Training_252']
#
# Batch IDs in Training Generator:
# Batch 0: ['BraTS20_Training_074', 'BraTS20_Training_220', 'BraTS20_Training_349', 'BraTS20_Training_238']
# Batch 1: ['BraTS20_Training_358', 'BraTS20_Training_069', 'BraTS20_Training_183', 'BraTS20_Training_306']
# Batch 2: ['BraTS20_Training_300', 'BraTS20_Training_314', 'BraTS20_Training_296', 'BraTS20_Training_264']
# Batch 3: ['BraTS20_Training_008', 'BraTS20_Training_113', 'BraTS20_Training_341', 'BraTS20_Training_226']
# Batch 4: ['BraTS20_Training_140', 'BraTS20_Training_013', 'BraTS20_Training_363', 'BraTS20_Training_193']
# Batch 5: ['BraTS20_Training_070', 'BraTS20_Training_184', 'BraTS20_Training_340', 'BraTS20_Training_061']
# Batch 6: ['BraTS20_Training_258', 'BraTS20_Training_142', 'BraTS20_Training_087', 'BraTS20_Training_282']
# Batch 7: ['BraTS20_Training_162', 'BraTS20_Training_063', 'BraTS20_Training_279', 'BraTS20_Training_071']
# Batch 8: ['BraTS20_Training_322', 'BraTS20_Training_229', 'BraTS20_Training_084', 'BraTS20_Training_022']
# Batch 9: ['BraTS20_Training_233', 'BraTS20_Training_018', 'BraTS20_Training_208', 'BraTS20_Training_248']
# Batch 10: ['BraTS20_Training_189', 'BraTS20_Training_353', 'BraTS20_Training_077', 'BraTS20_Training_147']
# Batch 11: ['BraTS20_Training_107', 'BraTS20_Training_175', 'BraTS20_Training_245', 'BraTS20_Training_064']
# Batch 12: ['BraTS20_Training_272', 'BraTS20_Training_160', 'BraTS20_Training_302', 'BraTS20_Training_088']
# Batch 13: ['BraTS20_Training_065', 'BraTS20_Training_369', 'BraTS20_Training_062', 'BraTS20_Training_344']
# Batch 14: ['BraTS20_Training_075', 'BraTS20_Training_057', 'BraTS20_Training_133', 'BraTS20_Training_321']
# Batch 15: ['BraTS20_Training_145', 'BraTS20_Training_037', 'BraTS20_Training_109', 'BraTS20_Training_261']
# Batch 16: ['BraTS20_Training_331', 'BraTS20_Training_081', 'BraTS20_Training_240', 'BraTS20_Training_197']
# Batch 17: ['BraTS20_Training_364', 'BraTS20_Training_135', 'BraTS20_Training_079', 'BraTS20_Training_192']
# Batch 18: ['BraTS20_Training_068', 'BraTS20_Training_187', 'BraTS20_Training_269', 'BraTS20_Training_067']
# Batch 19: ['BraTS20_Training_099', 'BraTS20_Training_016', 'BraTS20_Training_163', 'BraTS20_Training_174']
# Batch 20: ['BraTS20_Training_126', 'BraTS20_Training_365', 'BraTS20_Training_330', 'BraTS20_Training_354']
# Batch 21: ['BraTS20_Training_164', 'BraTS20_Training_097', 'BraTS20_Training_128', 'BraTS20_Training_317']
# Batch 22: ['BraTS20_Training_284', 'BraTS20_Training_270', 'BraTS20_Training_312', 'BraTS20_Training_124']
# Batch 23: ['BraTS20_Training_052', 'BraTS20_Training_082', 'BraTS20_Training_039', 'BraTS20_Training_027']
# Batch 24: ['BraTS20_Training_105', 'BraTS20_Training_287', 'BraTS20_Training_224', 'BraTS20_Training_011']
# Batch 25: ['BraTS20_Training_292', 'BraTS20_Training_228', 'BraTS20_Training_219', 'BraTS20_Training_020']
# Batch 26: ['BraTS20_Training_114', 'BraTS20_Training_036', 'BraTS20_Training_161', 'BraTS20_Training_214']
# Batch 27: ['BraTS20_Training_151', 'BraTS20_Training_298', 'BraTS20_Training_217', 'BraTS20_Training_273']
# Batch 28: ['BraTS20_Training_243', 'BraTS20_Training_239', 'BraTS20_Training_030', 'BraTS20_Training_098']
# Batch 29: ['BraTS20_Training_254', 'BraTS20_Training_335', 'BraTS20_Training_007', 'BraTS20_Training_246']
# Batch 30: ['BraTS20_Training_086', 'BraTS20_Training_188', 'BraTS20_Training_230', 'BraTS20_Training_346']
# Batch 31: ['BraTS20_Training_080', 'BraTS20_Training_280', 'BraTS20_Training_167', 'BraTS20_Training_315']
# Batch 32: ['BraTS20_Training_019', 'BraTS20_Training_032', 'BraTS20_Training_154', 'BraTS20_Training_152']
# Batch 33: ['BraTS20_Training_207', 'BraTS20_Training_301', 'BraTS20_Training_305', 'BraTS20_Training_348']
# Batch 34: ['BraTS20_Training_035', 'BraTS20_Training_112', 'BraTS20_Training_093', 'BraTS20_Training_144']
# Batch 35: ['BraTS20_Training_332', 'BraTS20_Training_275', 'BraTS20_Training_328', 'BraTS20_Training_165']
# Batch 36: ['BraTS20_Training_156', 'BraTS20_Training_333', 'BraTS20_Training_134', 'BraTS20_Training_195']
# Batch 37: ['BraTS20_Training_262', 'BraTS20_Training_166', 'BraTS20_Training_155', 'BraTS20_Training_313']
# Batch 38: ['BraTS20_Training_014', 'BraTS20_Training_234', 'BraTS20_Training_060', 'BraTS20_Training_048']
# Batch 39: ['BraTS20_Training_150', 'BraTS20_Training_091', 'BraTS20_Training_045', 'BraTS20_Training_329']
# Batch 40: ['BraTS20_Training_104', 'BraTS20_Training_215', 'BraTS20_Training_029', 'BraTS20_Training_327']
# Batch 41: ['BraTS20_Training_337', 'BraTS20_Training_078', 'BraTS20_Training_283', 'BraTS20_Training_253']
# Batch 42: ['BraTS20_Training_251', 'BraTS20_Training_355', 'BraTS20_Training_319', 'BraTS20_Training_218']
# Batch 43: ['BraTS20_Training_170', 'BraTS20_Training_257', 'BraTS20_Training_176', 'BraTS20_Training_204']
# Batch 44: ['BraTS20_Training_342', 'BraTS20_Training_005', 'BraTS20_Training_148', 'BraTS20_Training_050']
# Batch 45: ['BraTS20_Training_352', 'BraTS20_Training_362', 'BraTS20_Training_191', 'BraTS20_Training_293']
# Batch 46: ['BraTS20_Training_324', 'BraTS20_Training_111', 'BraTS20_Training_297', 'BraTS20_Training_138']
# Batch 47: ['BraTS20_Training_159', 'BraTS20_Training_100', 'BraTS20_Training_042', 'BraTS20_Training_173']
# Batch 48: ['BraTS20_Training_108', 'BraTS20_Training_194', 'BraTS20_Training_051', 'BraTS20_Training_172']
# Batch 49: ['BraTS20_Training_294', 'BraTS20_Training_196', 'BraTS20_Training_281', 'BraTS20_Training_180']
# Batch 50: ['BraTS20_Training_158', 'BraTS20_Training_265', 'BraTS20_Training_090', 'BraTS20_Training_249']
# Batch 51: ['BraTS20_Training_053', 'BraTS20_Training_286', 'BraTS20_Training_361', 'BraTS20_Training_089']
# Batch 52: ['BraTS20_Training_072', 'BraTS20_Training_024', 'BraTS20_Training_203', 'BraTS20_Training_211']
# Batch 53: ['BraTS20_Training_058', 'BraTS20_Training_366', 'BraTS20_Training_139', 'BraTS20_Training_250']
# Batch 54: ['BraTS20_Training_171', 'BraTS20_Training_121', 'BraTS20_Training_046', 'BraTS20_Training_326']
# Batch 55: ['BraTS20_Training_157', 'BraTS20_Training_338', 'BraTS20_Training_360', 'BraTS20_Training_186']
# Batch 56: ['BraTS20_Training_141', 'BraTS20_Training_303', 'BraTS20_Training_235', 'BraTS20_Training_092']
# Batch 57: ['BraTS20_Training_256', 'BraTS20_Training_127', 'BraTS20_Training_290', 'BraTS20_Training_129']
# Batch 58: ['BraTS20_Training_210', 'BraTS20_Training_221', 'BraTS20_Training_115', 'BraTS20_Training_242']
# Batch 59: ['BraTS20_Training_323', 'BraTS20_Training_168', 'BraTS20_Training_102', 'BraTS20_Training_263']
# Batch 60: ['BraTS20_Training_309', 'BraTS20_Training_368', 'BraTS20_Training_351', 'BraTS20_Training_179']
# Batch 61: ['BraTS20_Training_247', 'BraTS20_Training_143', 'BraTS20_Training_040', 'BraTS20_Training_120']
# Batch 62: ['BraTS20_Training_276', 'BraTS20_Training_367', 'BraTS20_Training_201', 'BraTS20_Training_125']
# Batch 63: ['BraTS20_Training_122', 'BraTS20_Training_182', 'BraTS20_Training_359', 'BraTS20_Training_149']
# Batch 64: ['BraTS20_Training_310', 'BraTS20_Training_237']
#
# Batch IDs in Validation Generator:
# Batch 0: ['BraTS20_Training_123', 'BraTS20_Training_318', 'BraTS20_Training_056', 'BraTS20_Training_026']
# Batch 1: ['BraTS20_Training_198', 'BraTS20_Training_350', 'BraTS20_Training_041', 'BraTS20_Training_038']
# Batch 2: ['BraTS20_Training_002', 'BraTS20_Training_271', 'BraTS20_Training_177', 'BraTS20_Training_006']
# Batch 3: ['BraTS20_Training_101', 'BraTS20_Training_137', 'BraTS20_Training_343', 'BraTS20_Training_001']
# Batch 4: ['BraTS20_Training_285', 'BraTS20_Training_199', 'BraTS20_Training_356', 'BraTS20_Training_009']
# Batch 5: ['BraTS20_Training_278', 'BraTS20_Training_033', 'BraTS20_Training_178', 'BraTS20_Training_223']
# Batch 6: ['BraTS20_Training_073', 'BraTS20_Training_146', 'BraTS20_Training_336', 'BraTS20_Training_339']
# Batch 7: ['BraTS20_Training_334', 'BraTS20_Training_028', 'BraTS20_Training_025', 'BraTS20_Training_357']
# Batch 8: ['BraTS20_Training_103', 'BraTS20_Training_169', 'BraTS20_Training_345', 'BraTS20_Training_190']
# Batch 9: ['BraTS20_Training_066', 'BraTS20_Training_289', 'BraTS20_Training_244', 'BraTS20_Training_055']
# Batch 10: ['BraTS20_Training_085', 'BraTS20_Training_236', 'BraTS20_Training_320', 'BraTS20_Training_205']
# Batch 11: ['BraTS20_Training_316', 'BraTS20_Training_119', 'BraTS20_Training_017', 'BraTS20_Training_181']
# Batch 12: ['BraTS20_Training_274', 'BraTS20_Training_117', 'BraTS20_Training_200', 'BraTS20_Training_110']
# Batch 13: ['BraTS20_Training_259', 'BraTS20_Training_049', 'BraTS20_Training_059']
#
# Batch IDs in Test Generator:
# Batch 0: ['BraTS20_Training_277', 'BraTS20_Training_015', 'BraTS20_Training_004', 'BraTS20_Training_095']
# Batch 1: ['BraTS20_Training_325', 'BraTS20_Training_153', 'BraTS20_Training_225', 'BraTS20_Training_206']
# Batch 2: ['BraTS20_Training_131', 'BraTS20_Training_034', 'BraTS20_Training_288', 'BraTS20_Training_010']
# Batch 3: ['BraTS20_Training_076', 'BraTS20_Training_308', 'BraTS20_Training_047', 'BraTS20_Training_023']
# Batch 4: ['BraTS20_Training_232', 'BraTS20_Training_185', 'BraTS20_Training_132', 'BraTS20_Training_106']
# Batch 5: ['BraTS20_Training_083', 'BraTS20_Training_295', 'BraTS20_Training_213', 'BraTS20_Training_202']
# Batch 6: ['BraTS20_Training_304', 'BraTS20_Training_222', 'BraTS20_Training_054', 'BraTS20_Training_118']
# Batch 7: ['BraTS20_Training_227', 'BraTS20_Training_021', 'BraTS20_Training_291', 'BraTS20_Training_216']
# Batch 8: ['BraTS20_Training_311', 'BraTS20_Training_003', 'BraTS20_Training_266', 'BraTS20_Training_255']
# Batch 9: ['BraTS20_Training_096', 'BraTS20_Training_044', 'BraTS20_Training_116', 'BraTS20_Training_252']
# Batch 10: ['BraTS20_Training_136', 'BraTS20_Training_212', 'BraTS20_Training_347', 'BraTS20_Training_260']
# Batch 11: ['BraTS20_Training_130', 'BraTS20_Training_267', 'BraTS20_Training_031', 'BraTS20_Training_241']
# Batch 12: ['BraTS20_Training_307', 'BraTS20_Training_043', 'BraTS20_Training_231', 'BraTS20_Training_209']
# Batch 13: ['BraTS20_Training_299', 'BraTS20_Training_268', 'BraTS20_Training_012', 'BraTS20_Training_094']

# %%
import csv

# Save training subject IDs
with open('train_subjects.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Subject ID'])
    for subject in train_ids:
        writer.writerow([subject])

# Save validation subject IDs
with open('validation_subjects.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Subject ID'])
    for subject in val_ids:
        writer.writerow([subject])

# Save test subject IDs
with open('test_subjects.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Subject ID'])
    for subject in test_ids:
        writer.writerow([subject])

# For training generator
with open('train_batches.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Batch Index', 'Subject IDs'])
    for i in range(len(training_generator)):
        batch_indices = training_generator.indexes[i * training_generator.batch_size:(i+1) * training_generator.batch_size]
        batch_ids = [training_generator.list_IDs[idx] for idx in batch_indices]
        writer.writerow([i, ','.join(batch_ids)])

# For validation generator
with open('validation_batches.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Batch Index', 'Subject IDs'])
    for i in range(len(valid_generator)):
        batch_indices = valid_generator.indexes[i * valid_generator.batch_size:(i+1) * valid_generator.batch_size]
        batch_ids = [valid_generator.list_IDs[idx] for idx in batch_indices]
        writer.writerow([i, ','.join(batch_ids)])

# For test generator
with open('test_batches.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Batch Index', 'Subject IDs'])
    for i in range(len(test_generator)):
        batch_indices = test_generator.indexes[i * test_generator.batch_size:(i+1) * test_generator.batch_size]
        batch_ids = [test_generator.list_IDs[idx] for idx in batch_indices]
        writer.writerow([i, ','.join(batch_ids)])
